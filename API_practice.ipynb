# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# # Create a practice set of random latitude and longitude combinations.
# lats = [25.12903645, 25.92017388, 26.62509167, -59.98969384, 37.30571269]
# lngs = [-67.59741259, 11.09532135, 74.84233102, -76.89176677, -61.13376282]
# lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ### You can only unzip tuple once before it is removed from the computer's memory. Make sure you unzip the latitudes and longitudes into the coordinates list before moving on.

# %%
# # Use the print() function to display the latitude and longitude combinations.
# for coordinate in coordinates:
#     print(coordinate[0], coordinate[1])

# %%
# Use the citipy module to determine city based on latitude and longitude. 
from citipy import citipy

# %%
# # Use the print() function to display the latitude and longitude combinations. 
# for coordinate in coordinates:
#     print(citipy.nearest_city(coordinate[0], coordinate[1]).city_name, 
#           citipy.nearest_city(coordinate[0], coordinate[1]).country_code)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and logitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 605

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URl for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=286ca73bb4158c98f2bfe56e4234c584

# %%
# Create and endpoint URL for a city.
city_url = url + "&q=" + "Boston"
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=286ca73bb4158c98f2bfe56e4234c584&q=Boston

# %%
# Make a "Get" request for the city wheather.
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
# Create am endpoint URL for a city.
city_url = url + "&q=" + "Bston"
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [404]>

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
# Get the text of the "Get" request.
city_weather.text
# Out:
# '{"coord":{"lon":-71.0598,"lat":42.3584},"weather":[{"id":802,"main":"Clouds","description":"scattered clouds","icon":"03d"}],"base":"stations","main":{"temp":74.26,"feels_like":73.89,"temp_min":68.95,"temp_max":80.4,"pressure":1021,"humidity":53},"visibility":10000,"wind":{"speed":8.01,"deg":159,"gust":14},"clouds":{"all":36},"dt":1655325747,"sys":{"type":2,"id":2013408,"country":"US","sunrise":1655284013,"sunset":1655338961},"timezone":-14400,"id":4930956,"name":"Boston","cod":200}'

# %%
# Get the JSON text of the "Get" request.
city_weather.json()
# Out:
# {'coord': {'lon': -71.0598, 'lat': 42.3584},
#  'weather': [{'id': 802,
#    'main': 'Clouds',
#    'description': 'scattered clouds',
#    'icon': '03d'}],
#  'base': 'stations',
#  'main': {'temp': 74.26,
#   'feels_like': 73.89,
#   'temp_min': 68.95,
#   'temp_max': 80.4,
#   'pressure': 1021,
#   'humidity': 53},
#  'visibility': 10000,
#  'wind': {'speed': 8.01, 'deg': 159, 'gust': 14},
#  'clouds': {'all': 36},
#  'dt': 1655325747,
#  'sys': {'type': 2,
#   'id': 2013408,
#   'country': 'US',
#   'sunrise': 1655284013,
#   'sunset': 1655338961},
#  'timezone': -14400,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
if city_weather.status_code == 200:
    print(f"City Weather found.")
else:
    print(f"City weather not found.")
# Out:
# City Weather found.

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Bston"
city_weather = requests.get(city_url)
if city_weather.status_code == 200:
    print(f"City Weather found.")
else:
    print(f"City weather not found.")
# Out:
# City weather not found.

# %%
# Create an endpoint URL for a city
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather.json()
# Out:
# {'coord': {'lon': -71.0598, 'lat': 42.3584},
#  'weather': [{'id': 802,
#    'main': 'Clouds',
#    'description': 'scattered clouds',
#    'icon': '03d'}],
#  'base': 'stations',
#  'main': {'temp': 74.26,
#   'feels_like': 73.89,
#   'temp_min': 68.95,
#   'temp_max': 80.4,
#   'pressure': 1021,
#   'humidity': 53},
#  'visibility': 10000,
#  'wind': {'speed': 8.01, 'deg': 159, 'gust': 14},
#  'clouds': {'all': 36},
#  'dt': 1655325747,
#  'sys': {'type': 2,
#   'id': 2013408,
#   'country': 'US',
#   'sunrise': 1655284013,
#   'sunset': 1655338961},
#  'timezone': -14400,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# Get the JSON data.
boston_data = city_weather.json()

# %%
boston_data["sys"]
# Out:
# {'type': 2,
#  'id': 2013408,
#  'country': 'US',
#  'sunrise': 1655284013,
#  'sunset': 1655338961}

# %%
boston_data["sys"]["country"]
# Out:
# 'US'

# %%
boston_data["dt"]
# Out:
# 1655325747

# %%
lat = boston_data["coord"]["lat"]
lng = boston_data["coord"]["lon"]
max_temp = boston_data["main"]["temp_max"]
humidity = boston_data["main"]["humidity"]
clouds = boston_data["clouds"]["all"]
wind = boston_data["wind"]["speed"]
print(lat, lng, max_temp, humidity, clouds, wind)
# Out:
# 42.3584 -71.0598 80.4 53 36 8.01

# %%
boston_data["dt"]
# Out:
# 1655325747

# %%
# Import the datetime module from the datetime library.
from datetime import datetime
# Get the date from the JSON file.
date = boston_data["dt"]
# Convert the UTC date to date format with year, month, day, hours, minutes, and seconds.
datetime.utcfromtimestamp(date)
# Out:
# datetime.datetime(2022, 6, 15, 20, 42, 27)

# %%
datetime.utcfromtimestamp(date).strftime('%Y-%m-%d %H:%M:%S')
# Out:
# '2022-06-15 20:42:27'

# %%
# Import the time library and the datetime module from the datetime library
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data. 
city_data = []
# Print the beginning of the logging. 
print("Beginning Data Retrieval    ")
print("----------------------------")
# Create counters.
record_count =1
set_count = 1

# Create an empty list to hold the weather data. 
city_data = []
# Print the beginning of the logging. 
print("Beginning Data Retrieval    ")
print("----------------------------")
# Create counters.
record_count =1
set_count = 1# Loop through all the cities in the list.
for i, city in enumerate(cities):
    # Group cities in sets of 5o for logging purposes.
    if (i %  50 == 0 and i>= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    #Log the URL, record, and set numbers and the city. 
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# ----------------------------
# Beginning Data Retrieval
# ----------------------------
# Processing Record 1 of Set 1 | twin falls
# Processing Record 2 of Set 1 | kavieng
# Processing Record 3 of Set 1 | nikolayevka
# Processing Record 4 of Set 1 | buala
# Processing Record 5 of Set 1 | albany
# Processing Record 6 of Set 1 | yellowknife
# Processing Record 7 of Set 1 | oxford
# Processing Record 8 of Set 1 | halalo
# City not found. Skipping...
# Processing Record 9 of Set 1 | punta arenas
# Processing Record 10 of Set 1 | butaritari
# Processing Record 11 of Set 1 | alice springs
# Processing Record 12 of Set 1 | kapaa
# Processing Record 13 of Set 1 | ushuaia
# Processing Record 14 of Set 1 | carnarvon
# Processing Record 15 of Set 1 | lolua
# City not found. Skipping...
# Processing Record 16 of Set 1 | severo-kurilsk
# Processing Record 17 of Set 1 | yar-sale
# Processing Record 18 of Set 1 | leningradskiy
# Processing Record 19 of Set 1 | geraldton
# Processing Record 20 of Set 1 | terme
# Processing Record 21 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 22 of Set 1 | beringovskiy
# Processing Record 23 of Set 1 | port alfred
# Processing Record 24 of Set 1 | atar
# Processing Record 25 of Set 1 | kalemie
# Processing Record 26 of Set 1 | boyolangu
# Processing Record 27 of Set 1 | tasiilaq
# Processing Record 28 of Set 1 | georgetown
# Processing Record 29 of Set 1 | dolores
# Processing Record 30 of Set 1 | busselton
# Processing Record 31 of Set 1 | avarua
# Processing Record 32 of Set 1 | coahuayana
# Processing Record 33 of Set 1 | handan
# Processing Record 34 of Set 1 | sao joao da barra
# Processing Record 35 of Set 1 | hilo
# Processing Record 36 of Set 1 | norman wells
# Processing Record 37 of Set 1 | pathein
# Processing Record 38 of Set 1 | dzilam gonzalez
# Processing Record 39 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 40 of Set 1 | manono
# Processing Record 41 of Set 1 | katsuura
# Processing Record 42 of Set 1 | jamestown
# Processing Record 43 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 44 of Set 1 | saint-philippe
# Processing Record 45 of Set 1 | chokurdakh
# Processing Record 46 of Set 1 | nemuro
# Processing Record 47 of Set 1 | provideniya
# Processing Record 48 of Set 1 | klyuchi
# Processing Record 49 of Set 1 | ribeira grande
# Processing Record 50 of Set 1 | bredasdorp
# Processing Record 1 of Set 2 | ostrovnoy
# Processing Record 2 of Set 2 | goderich
# Processing Record 3 of Set 2 | dolbeau
# City not found. Skipping...
# Processing Record 4 of Set 2 | pike creek
# Processing Record 5 of Set 2 | babanusah
# City not found. Skipping...
# Processing Record 6 of Set 2 | poum
# Processing Record 7 of Set 2 | angoche
# Processing Record 8 of Set 2 | akyab
# Processing Record 9 of Set 2 | willowmore
# Processing Record 10 of Set 2 | tilichiki
# Processing Record 11 of Set 2 | necochea
# Processing Record 12 of Set 2 | auki
# Processing Record 13 of Set 2 | serta
# Processing Record 14 of Set 2 | cayenne
# Processing Record 15 of Set 2 | gat
# Processing Record 16 of Set 2 | cape town
# Processing Record 17 of Set 2 | trairi
# Processing Record 18 of Set 2 | aksarka
# Processing Record 19 of Set 2 | djambala
# Processing Record 20 of Set 2 | ramgarh
# Processing Record 21 of Set 2 | torbay
# Processing Record 22 of Set 2 | fairbanks
# Processing Record 23 of Set 2 | waipawa
# Processing Record 24 of Set 2 | vaini
# Processing Record 25 of Set 2 | bluff
# Processing Record 26 of Set 2 | victoria
# Processing Record 27 of Set 2 | linfen
# Processing Record 28 of Set 2 | homer
# Processing Record 29 of Set 2 | adrano
# Processing Record 30 of Set 2 | ilulissat
# Processing Record 31 of Set 2 | datong
# Processing Record 32 of Set 2 | severnyy
# Processing Record 33 of Set 2 | kaitangata
# Processing Record 34 of Set 2 | mataura
# Processing Record 35 of Set 2 | east london
# Processing Record 36 of Set 2 | touros
# Processing Record 37 of Set 2 | nikolskoye
# Processing Record 38 of Set 2 | samastipur
# Processing Record 39 of Set 2 | ancud
# Processing Record 40 of Set 2 | klaksvik
# Processing Record 41 of Set 2 | chuy
# Processing Record 42 of Set 2 | sol-iletsk
# Processing Record 43 of Set 2 | sukumo
# Processing Record 44 of Set 2 | san rafael
# Processing Record 45 of Set 2 | clyde river
# Processing Record 46 of Set 2 | tuktoyaktuk
# Processing Record 47 of Set 2 | hithadhoo
# Processing Record 48 of Set 2 | rikitea
# Processing Record 49 of Set 2 | gladstone
# Processing Record 50 of Set 2 | sola
# Processing Record 1 of Set 3 | aklavik
# Processing Record 2 of Set 3 | kavaratti
# Processing Record 3 of Set 3 | quatre cocos
# Processing Record 4 of Set 3 | mahibadhoo
# Processing Record 5 of Set 3 | puerto ayora
# Processing Record 6 of Set 3 | bambanglipuro
# Processing Record 7 of Set 3 | weligama
# Processing Record 8 of Set 3 | mahebourg
# Processing Record 9 of Set 3 | bintulu
# Processing Record 10 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 11 of Set 3 | rio gallegos
# Processing Record 12 of Set 3 | dikson
# Processing Record 13 of Set 3 | pavino
# Processing Record 14 of Set 3 | karamay
# City not found. Skipping...
# Processing Record 15 of Set 3 | port elizabeth
# Processing Record 16 of Set 3 | qaanaaq
# Processing Record 17 of Set 3 | hobart
# Processing Record 18 of Set 3 | kiruna
# Processing Record 19 of Set 3 | airai
# Processing Record 20 of Set 3 | saint george
# Processing Record 21 of Set 3 | cidreira
# Processing Record 22 of Set 3 | isangel
# Processing Record 23 of Set 3 | coihaique
# Processing Record 24 of Set 3 | sakakah
# Processing Record 25 of Set 3 | christchurch
# Processing Record 26 of Set 3 | alotau
# City not found. Skipping...
# Processing Record 27 of Set 3 | flin flon
# Processing Record 28 of Set 3 | tuatapere
# Processing Record 29 of Set 3 | le portel
# Processing Record 30 of Set 3 | bodden town
# Processing Record 31 of Set 3 | comodoro rivadavia
# Processing Record 32 of Set 3 | kamaishi
# Processing Record 33 of Set 3 | manubul
# Processing Record 34 of Set 3 | timbiqui
# Processing Record 35 of Set 3 | nantucket
# Processing Record 36 of Set 3 | lorengau
# Processing Record 37 of Set 3 | lohfelden
# Processing Record 38 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 39 of Set 3 | narsaq
# Processing Record 40 of Set 3 | dibai
# Processing Record 41 of Set 3 | barmer
# Processing Record 42 of Set 3 | castro
# Processing Record 43 of Set 3 | maarianhamina
# Processing Record 44 of Set 3 | partapur
# Processing Record 45 of Set 3 | tura
# Processing Record 46 of Set 3 | mar del plata
# Processing Record 47 of Set 3 | betsiamites
# Processing Record 48 of Set 3 | khatanga
# Processing Record 49 of Set 3 | constitucion
# Processing Record 50 of Set 3 | igarka
# Processing Record 1 of Set 4 | bethel
# Processing Record 2 of Set 4 | ngukurr
# City not found. Skipping...
# Processing Record 3 of Set 4 | buchanan
# Processing Record 4 of Set 4 | tiksi
# Processing Record 5 of Set 4 | ust-nera
# Processing Record 6 of Set 4 | deputatskiy
# Processing Record 7 of Set 4 | hermanus
# Processing Record 8 of Set 4 | lar gerd
# City not found. Skipping...
# Processing Record 9 of Set 4 | tautira
# Processing Record 10 of Set 4 | portland
# Processing Record 11 of Set 4 | sembakung
# Processing Record 12 of Set 4 | koumac
# Processing Record 13 of Set 4 | kruisfontein
# Processing Record 14 of Set 4 | garowe
# Processing Record 15 of Set 4 | beira
# Processing Record 16 of Set 4 | luderitz
# Processing Record 17 of Set 4 | ponta delgada
# Processing Record 18 of Set 4 | pauini
# Processing Record 19 of Set 4 | mocambique
# City not found. Skipping...
# Processing Record 20 of Set 4 | hasaki
# Processing Record 21 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 22 of Set 4 | arraial do cabo
# Processing Record 23 of Set 4 | saskylakh
# Processing Record 24 of Set 4 | taoudenni
# Processing Record 25 of Set 4 | talnakh
# Processing Record 26 of Set 4 | ishigaki
# Processing Record 27 of Set 4 | palmer
# Processing Record 28 of Set 4 | kuching
# Processing Record 29 of Set 4 | port hedland
# Processing Record 30 of Set 4 | victor harbor
# Processing Record 31 of Set 4 | dudinka
# Processing Record 32 of Set 4 | hihifo
# City not found. Skipping...
# Processing Record 33 of Set 4 | bathsheba
# Processing Record 34 of Set 4 | coxim
# Processing Record 35 of Set 4 | jerez
# Processing Record 36 of Set 4 | vardo
# Processing Record 37 of Set 4 | dumas
# Processing Record 38 of Set 4 | kyshtovka
# Processing Record 39 of Set 4 | merrill
# Processing Record 40 of Set 4 | mogok
# Processing Record 41 of Set 4 | camacha
# Processing Record 42 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 43 of Set 4 | mapastepec
# Processing Record 44 of Set 4 | shache
# Processing Record 45 of Set 4 | sovetskaya gavan
# Processing Record 46 of Set 4 | atuona
# Processing Record 47 of Set 4 | acapulco
# Processing Record 48 of Set 4 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 49 of Set 4 | kashi
# Processing Record 50 of Set 4 | bam
# Processing Record 1 of Set 5 | san patricio
# Processing Record 2 of Set 5 | pribelskiy
# City not found. Skipping...
# Processing Record 3 of Set 5 | wagar
# Processing Record 4 of Set 5 | kamina
# Processing Record 5 of Set 5 | henties bay
# Processing Record 6 of Set 5 | pangnirtung
# Processing Record 7 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 8 of Set 5 | malanje
# Processing Record 9 of Set 5 | caravelas
# Processing Record 10 of Set 5 | brae
# Processing Record 11 of Set 5 | bambous virieux
# Processing Record 12 of Set 5 | toliary
# City not found. Skipping...
# Processing Record 13 of Set 5 | amontada
# Processing Record 14 of Set 5 | grand gaube
# Processing Record 15 of Set 5 | andros town
# Processing Record 16 of Set 5 | hammerfest
# Processing Record 17 of Set 5 | pevek
# Processing Record 18 of Set 5 | banda aceh
# Processing Record 19 of Set 5 | cockburn harbour
# City not found. Skipping...
# Processing Record 20 of Set 5 | meulaboh
# Processing Record 21 of Set 5 | mullaitivu
# City not found. Skipping...
# Processing Record 22 of Set 5 | sorvag
# City not found. Skipping...
# Processing Record 23 of Set 5 | nouadhibou
# Processing Record 24 of Set 5 | adrar
# Processing Record 25 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 26 of Set 5 | sisimiut
# Processing Record 27 of Set 5 | ngunguru
# Processing Record 28 of Set 5 | cherskiy
# Processing Record 29 of Set 5 | sorland
# Processing Record 30 of Set 5 | mareeba
# Processing Record 31 of Set 5 | karkaralinsk
# City not found. Skipping...
# Processing Record 32 of Set 5 | kulhudhuffushi
# Processing Record 33 of Set 5 | koulamoutou
# Processing Record 34 of Set 5 | bengkulu
# Processing Record 35 of Set 5 | bolobo
# Processing Record 36 of Set 5 | parabel
# Processing Record 37 of Set 5 | tommot
# Processing Record 38 of Set 5 | diego de almagro
# Processing Record 39 of Set 5 | upernavik
# Processing Record 40 of Set 5 | tumaco
# Processing Record 41 of Set 5 | socoltenango
# Processing Record 42 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 43 of Set 5 | volovo
# Processing Record 44 of Set 5 | kayerkan
# Processing Record 45 of Set 5 | lompoc
# Processing Record 46 of Set 5 | riyadh
# Processing Record 47 of Set 5 | iqaluit
# Processing Record 48 of Set 5 | montepuez
# Processing Record 49 of Set 5 | sao filipe
# Processing Record 50 of Set 5 | superior
# Processing Record 1 of Set 6 | muisne
# Processing Record 2 of Set 6 | hambantota
# Processing Record 3 of Set 6 | seguela
# Processing Record 4 of Set 6 | lavrentiya
# Processing Record 5 of Set 6 | xai-xai
# Processing Record 6 of Set 6 | padang
# Processing Record 7 of Set 6 | boa vista
# Processing Record 8 of Set 6 | flinders
# Processing Record 9 of Set 6 | warwick
# Processing Record 10 of Set 6 | esperance
# Processing Record 11 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 12 of Set 6 | potam
# Processing Record 13 of Set 6 | xiongzhou
# Processing Record 14 of Set 6 | haibowan
# City not found. Skipping...
# Processing Record 15 of Set 6 | urucara
# Processing Record 16 of Set 6 | longyearbyen
# Processing Record 17 of Set 6 | jalu
# Processing Record 18 of Set 6 | honiara
# Processing Record 19 of Set 6 | redlands
# Processing Record 20 of Set 6 | havre-saint-pierre
# Processing Record 21 of Set 6 | kemijarvi
# Processing Record 22 of Set 6 | paamiut
# Processing Record 23 of Set 6 | avera
# Processing Record 24 of Set 6 | new norfolk
# Processing Record 25 of Set 6 | bilibino
# Processing Record 26 of Set 6 | huarmey
# Processing Record 27 of Set 6 | tripoli
# Processing Record 28 of Set 6 | cabo san lucas
# Processing Record 29 of Set 6 | iisalmi
# Processing Record 30 of Set 6 | tidore
# City not found. Skipping...
# Processing Record 31 of Set 6 | karaul
# City not found. Skipping...
# Processing Record 32 of Set 6 | yagodnoye
# Processing Record 33 of Set 6 | qui nhon
# Processing Record 34 of Set 6 | vestmannaeyjar
# Processing Record 35 of Set 6 | wasilla
# Processing Record 36 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 37 of Set 6 | bentiu
# Processing Record 38 of Set 6 | pemberton
# Processing Record 39 of Set 6 | san policarpo
# Processing Record 40 of Set 6 | vila franca do campo
# Processing Record 41 of Set 6 | arosa
# Processing Record 42 of Set 6 | lufilufi
# Processing Record 43 of Set 6 | griffith
# Processing Record 44 of Set 6 | mao
# Processing Record 45 of Set 6 | kokopo
# Processing Record 46 of Set 6 | kakrala
# Processing Record 47 of Set 6 | saldanha
# Processing Record 48 of Set 6 | maghama
# City not found. Skipping...
# Processing Record 49 of Set 6 | nanortalik
# Processing Record 50 of Set 6 | sao felix do xingu
# Processing Record 1 of Set 7 | imeni babushkina
# Processing Record 2 of Set 7 | kindu
# Processing Record 3 of Set 7 | ambilobe
# Processing Record 4 of Set 7 | port macquarie
# Processing Record 5 of Set 7 | ponta do sol
# Processing Record 6 of Set 7 | norwich
# Processing Record 7 of Set 7 | bur gabo
# City not found. Skipping...
# Processing Record 8 of Set 7 | waddan
# Processing Record 9 of Set 7 | okrika
# Processing Record 10 of Set 7 | artyk
# City not found. Skipping...
# Processing Record 11 of Set 7 | macaboboni
# City not found. Skipping...
# Processing Record 12 of Set 7 | skjervoy
# Processing Record 13 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 14 of Set 7 | belushya guba
# City not found. Skipping...
# Processing Record 15 of Set 7 | sagar
# Processing Record 16 of Set 7 | louisbourg
# City not found. Skipping...
# Processing Record 17 of Set 7 | opuwo
# Processing Record 18 of Set 7 | tingo maria
# Processing Record 19 of Set 7 | barcelos
# Processing Record 20 of Set 7 | charters towers
# Processing Record 21 of Set 7 | meyungs
# City not found. Skipping...
# Processing Record 22 of Set 7 | north bend
# Processing Record 23 of Set 7 | nosivka
# Processing Record 24 of Set 7 | campbeltown
# Processing Record 25 of Set 7 | namibe
# Processing Record 26 of Set 7 | mabaruma
# Processing Record 27 of Set 7 | raga
# Processing Record 28 of Set 7 | fortuna
# Processing Record 29 of Set 7 | coquimbo
# Processing Record 30 of Set 7 | jamsa
# Processing Record 31 of Set 7 | porto novo
# Processing Record 32 of Set 7 | wajima
# Processing Record 33 of Set 7 | praia
# Processing Record 34 of Set 7 | coruripe
# Processing Record 35 of Set 7 | benghazi
# Processing Record 36 of Set 7 | ahipara
# Processing Record 37 of Set 7 | mishan
# Processing Record 38 of Set 7 | madarounfa
# Processing Record 39 of Set 7 | najran
# Processing Record 40 of Set 7 | abidjan
# Processing Record 41 of Set 7 | khash
# Processing Record 42 of Set 7 | george
# Processing Record 43 of Set 7 | singaraja
# Processing Record 44 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 45 of Set 7 | maralal
# Processing Record 46 of Set 7 | moroni
# Processing Record 47 of Set 7 | compostela
# Processing Record 48 of Set 7 | sur
# Processing Record 49 of Set 7 | ilorin
# Processing Record 50 of Set 7 | zhezkazgan
# Processing Record 1 of Set 8 | haines junction
# Processing Record 2 of Set 8 | batsfjord
# Processing Record 3 of Set 8 | sioux lookout
# Processing Record 4 of Set 8 | pisco
# Processing Record 5 of Set 8 | acarau
# Processing Record 6 of Set 8 | villaviciosa
# Processing Record 7 of Set 8 | talas
# Processing Record 8 of Set 8 | fort-shevchenko
# Processing Record 9 of Set 8 | lieksa
# Processing Record 10 of Set 8 | vila velha
# Processing Record 11 of Set 8 | barrow
# Processing Record 12 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 13 of Set 8 | yagoua
# Processing Record 14 of Set 8 | oussouye
# Processing Record 15 of Set 8 | cockburn town
# Processing Record 16 of Set 8 | kuhdasht
# Processing Record 17 of Set 8 | gazanjyk
# Processing Record 18 of Set 8 | sitka
# Processing Record 19 of Set 8 | chapais
# Processing Record 20 of Set 8 | byron bay
# Processing Record 21 of Set 8 | kahului
# Processing Record 22 of Set 8 | brainerd
# Processing Record 23 of Set 8 | le port
# Processing Record 24 of Set 8 | faya
# Processing Record 25 of Set 8 | samarai
# Processing Record 26 of Set 8 | kodiak
# Processing Record 27 of Set 8 | dragor
# Processing Record 28 of Set 8 | babu
# Processing Record 29 of Set 8 | sinjai
# Processing Record 30 of Set 8 | maple creek
# Processing Record 31 of Set 8 | yaan
# Processing Record 32 of Set 8 | hamilton
# Processing Record 33 of Set 8 | bursol
# City not found. Skipping...
# Processing Record 34 of Set 8 | paso de carrasco
# Processing Record 35 of Set 8 | rzhaksa
# Processing Record 36 of Set 8 | luganville
# Processing Record 37 of Set 8 | crateus
# Processing Record 38 of Set 8 | ngama
# Processing Record 39 of Set 8 | samalaeulu
# City not found. Skipping...
# Processing Record 40 of Set 8 | aykhal
# Processing Record 41 of Set 8 | santarem
# Processing Record 42 of Set 8 | esna
# Processing Record 43 of Set 8 | dezhou
# Processing Record 44 of Set 8 | baker city
# Processing Record 45 of Set 8 | khalkhal
# Processing Record 46 of Set 8 | dunedin
# Processing Record 47 of Set 8 | changde
# Processing Record 48 of Set 8 | evinayong
# Processing Record 49 of Set 8 | tukrah
# Processing Record 50 of Set 8 | balkanabat
# Processing Record 1 of Set 9 | kasongo
# Processing Record 2 of Set 9 | opelousas
# Processing Record 3 of Set 9 | wilmington
# Processing Record 4 of Set 9 | bermejo
# Processing Record 5 of Set 9 | glendive
# Processing Record 6 of Set 9 | kaa-khem
# Processing Record 7 of Set 9 | finschhafen
# Processing Record 8 of Set 9 | voyvozh
# Processing Record 9 of Set 9 | flagstaff
# Processing Record 10 of Set 9 | valparaiso
# Processing Record 11 of Set 9 | kisoro
# Processing Record 12 of Set 9 | tabou
# Processing Record 13 of Set 9 | alekseyevsk
# Processing Record 14 of Set 9 | langsa
# Processing Record 15 of Set 9 | balabac
# Processing Record 16 of Set 9 | axim
# Processing Record 17 of Set 9 | mokhsogollokh
# Processing Record 18 of Set 9 | codrington
# Processing Record 19 of Set 9 | wolmaranstad
# City not found. Skipping...
# Processing Record 20 of Set 9 | port blair
# Processing Record 21 of Set 9 | san quintin
# Processing Record 22 of Set 9 | synya
# Processing Record 23 of Set 9 | bosobolo
# Processing Record 24 of Set 9 | el retorno
# Processing Record 25 of Set 9 | fuyang
# Processing Record 26 of Set 9 | mandalgovi
# Processing Record 27 of Set 9 | gadung
# Processing Record 28 of Set 9 | nadym
# Processing Record 29 of Set 9 | kloulklubed
# Processing Record 30 of Set 9 | qasigiannguit
# Processing Record 31 of Set 9 | moussoro
# Processing Record 32 of Set 9 | lagoa
# Processing Record 33 of Set 9 | sinnamary
# Processing Record 34 of Set 9 | leh
# Processing Record 35 of Set 9 | kastamonu
# Processing Record 36 of Set 9 | abu samrah
# Processing Record 37 of Set 9 | qaqortoq
# Processing Record 38 of Set 9 | severobaykalsk
# Processing Record 39 of Set 9 | yarmouth
# Processing Record 40 of Set 9 | karauzyak
# City not found. Skipping...
# Processing Record 41 of Set 9 | matara
# Processing Record 42 of Set 9 | manokwari
# Processing Record 43 of Set 9 | laguna
# Processing Record 44 of Set 9 | faanui
# Processing Record 45 of Set 9 | saint-augustin
# Processing Record 46 of Set 9 | baykit
# Processing Record 47 of Set 9 | ulladulla
# Processing Record 48 of Set 9 | preobrazheniye
# Processing Record 49 of Set 9 | logansport
# Processing Record 50 of Set 9 | glazov
# Processing Record 1 of Set 10 | ola
# Processing Record 2 of Set 10 | arman
# Processing Record 3 of Set 10 | nova granada
# Processing Record 4 of Set 10 | salalah
# Processing Record 5 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 6 of Set 10 | sibolga
# Processing Record 7 of Set 10 | srednekolymsk
# Processing Record 8 of Set 10 | farah
# Processing Record 9 of Set 10 | abalak
# Processing Record 10 of Set 10 | kyzyl-suu
# Processing Record 11 of Set 10 | bargal
# City not found. Skipping...
# Processing Record 12 of Set 10 | gewane
# Processing Record 13 of Set 10 | cortez
# Processing Record 14 of Set 10 | aksha
# Processing Record 15 of Set 10 | richard toll
# City not found. Skipping...
# Processing Record 16 of Set 10 | lebu
# Processing Record 17 of Set 10 | jinxiang
# Processing Record 18 of Set 10 | xinqing
# Processing Record 19 of Set 10 | trinidad
# Processing Record 20 of Set 10 | kuala kedah
# Processing Record 21 of Set 10 | nago
# Processing Record 22 of Set 10 | alofi
# Processing Record 23 of Set 10 | robertsport
# Processing Record 24 of Set 10 | thompson
# Processing Record 25 of Set 10 | phan thiet
# Processing Record 26 of Set 10 | hofn
# Processing Record 27 of Set 10 | laureles
# Processing Record 28 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 29 of Set 10 | havoysund
# Processing Record 30 of Set 10 | osoyoos
# Processing Record 31 of Set 10 | hay river
# Processing Record 32 of Set 10 | lasa
# Processing Record 33 of Set 10 | itatinga
# Processing Record 34 of Set 10 | stockach
# Processing Record 35 of Set 10 | kieta
# Processing Record 36 of Set 10 | atasu
# Processing Record 37 of Set 10 | shahpura
# Processing Record 38 of Set 10 | semme
# Processing Record 39 of Set 10 | karratha
# Processing Record 40 of Set 10 | matay
# Processing Record 41 of Set 10 | nishihara
# Processing Record 42 of Set 10 | eyl
# Processing Record 43 of Set 10 | chiali
# City not found. Skipping...
# Processing Record 44 of Set 10 | mecca
# Processing Record 45 of Set 10 | ouesso
# Processing Record 46 of Set 10 | humberto de campos
# Processing Record 47 of Set 10 | skibbereen
# Processing Record 48 of Set 10 | tigzirt
# Processing Record 49 of Set 10 | puerto princesa
# Processing Record 50 of Set 10 | port hardy
# Processing Record 1 of Set 11 | koshurnikovo
# Processing Record 2 of Set 11 | uray
# Processing Record 3 of Set 11 | khawhai
# Processing Record 4 of Set 11 | churapcha
# Processing Record 5 of Set 11 | guerrero negro
# Processing Record 6 of Set 11 | prince rupert
# Processing Record 7 of Set 11 | jieshi
# Processing Record 8 of Set 11 | bainbridge
# Processing Record 9 of Set 11 | saint anthony
# Processing Record 10 of Set 11 | blagoveshchenka
# Processing Record 11 of Set 11 | malindi
# Processing Record 12 of Set 11 | mul
# Processing Record 13 of Set 11 | pravokubanskiy
# Processing Record 14 of Set 11 | yumen
# Processing Record 15 of Set 11 | tarhunah
# City not found. Skipping...
# Processing Record 16 of Set 11 | vavozh
# Processing Record 17 of Set 11 | alto araguaia
# Processing Record 18 of Set 11 | liku
# Processing Record 19 of Set 11 | seoul
# Processing Record 20 of Set 11 | khandbari
# Processing Record 21 of Set 11 | novikovo
# Processing Record 22 of Set 11 | kirakira
# Processing Record 23 of Set 11 | jibuti
# Processing Record 24 of Set 11 | el alto
# Processing Record 25 of Set 11 | moose factory
# Processing Record 26 of Set 11 | college
# Processing Record 27 of Set 11 | mackay
# Processing Record 28 of Set 11 | sudogda
# Processing Record 29 of Set 11 | shar
# Processing Record 30 of Set 11 | xuanhua
# Processing Record 31 of Set 11 | say
# Processing Record 32 of Set 11 | kishapu
# Processing Record 33 of Set 11 | komsomolskiy
# Processing Record 34 of Set 11 | nagorsk
# Processing Record 35 of Set 11 | mnogovershinnyy
# Processing Record 36 of Set 11 | mount gambier
# Processing Record 37 of Set 11 | litoral del san juan
# City not found. Skipping...
# Processing Record 38 of Set 11 | oistins
# Processing Record 39 of Set 11 | anadyr
# Processing Record 40 of Set 11 | nioro
# Processing Record 41 of Set 11 | richmond
# Processing Record 42 of Set 11 | vikulovo
# Processing Record 43 of Set 11 | kattivakkam
# Processing Record 44 of Set 11 | okha
# Processing Record 45 of Set 11 | siva
# Processing Record 46 of Set 11 | jinchengjiang
# City not found. Skipping...
# Processing Record 47 of Set 11 | vizinga
# Processing Record 48 of Set 11 | anahuac
# Processing Record 49 of Set 11 | dahuk
# Processing Record 50 of Set 11 | edd
# Processing Record 1 of Set 12 | sault sainte marie
# Processing Record 2 of Set 12 | tevaitoa
# Processing Record 3 of Set 12 | salym
# Processing Record 4 of Set 12 | seminole
# Processing Record 5 of Set 12 | fevralsk
# City not found. Skipping...
# Processing Record 6 of Set 12 | esik
# Processing Record 7 of Set 12 | miri
# Processing Record 8 of Set 12 | bocaiuva
# Processing Record 9 of Set 12 | souillac
# Processing Record 10 of Set 12 | kutum
# Processing Record 11 of Set 12 | imperia
# Processing Record 12 of Set 12 | beloha
# Processing Record 13 of Set 12 | gumushane
# City not found. Skipping...
# Processing Record 14 of Set 12 | saint-michel-des-saints
# Processing Record 15 of Set 12 | bilma
# Processing Record 16 of Set 12 | olinda
# Processing Record 17 of Set 12 | khonuu
# City not found. Skipping...
# Processing Record 18 of Set 12 | serpong
# Processing Record 19 of Set 12 | dinsor
# City not found. Skipping...
# Processing Record 20 of Set 12 | nha trang
# Processing Record 21 of Set 12 | honolulu
# Processing Record 22 of Set 12 | zhigansk
# Processing Record 23 of Set 12 | dong xoai
# Processing Record 24 of Set 12 | filadelfia
# Processing Record 25 of Set 12 | inirida
# Processing Record 26 of Set 12 | bayshore gardens
# Processing Record 27 of Set 12 | san jose
# Processing Record 28 of Set 12 | baruun-urt
# Processing Record 29 of Set 12 | belogorsk
# Processing Record 30 of Set 12 | longhua
# Processing Record 31 of Set 12 | notse
# Processing Record 32 of Set 12 | lodja
# Processing Record 33 of Set 12 | mogwase
# Processing Record 34 of Set 12 | beoumi
# Processing Record 35 of Set 12 | mundra
# Processing Record 36 of Set 12 | zhuhai
# Processing Record 37 of Set 12 | pacific grove
# Processing Record 38 of Set 12 | sorong
# Processing Record 39 of Set 12 | dehloran
# Processing Record 40 of Set 12 | casablanca
# Processing Record 41 of Set 12 | sidney
# Processing Record 42 of Set 12 | shenzhen
# Processing Record 43 of Set 12 | palauig
# Processing Record 44 of Set 12 | hobyo
# Processing Record 45 of Set 12 | rehti
# Processing Record 46 of Set 12 | russell
# Processing Record 47 of Set 12 | inza
# Processing Record 48 of Set 12 | pierre
# Processing Record 49 of Set 12 | serenje
# Processing Record 50 of Set 12 | poyarkovo
# Processing Record 1 of Set 13 | orumiyeh
# Processing Record 2 of Set 13 | skagastrond
# City not found. Skipping...
# Processing Record 3 of Set 13 | mentok
# City not found. Skipping...
# Processing Record 4 of Set 13 | namatanai
# Processing Record 5 of Set 13 | wattegama
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Twin Falls  42.3505 -114.6445     64.92        26           0
# 1        Kavieng  -2.5744  150.7967     82.17        76          17
# 2    Nikolayevka  53.1257   47.2041     61.79        80          90
# 3          Buala  -8.1450  159.5921     81.00        81          99
# 4         Albany  42.6001  -73.9662     84.58        44          77
# 5    Yellowknife  62.4560 -114.3525     72.12        40          75
# 6         Oxford  51.7522   -1.2560     68.16        45           0
# 7   Punta Arenas -53.1500  -70.9167     44.71        65          75
# 8     Butaritari   3.0707  172.7902     81.93        68          88
# 9  Alice Springs -23.7000  133.8833     40.55        87          16
#
#    Wind Speed Country                 Date
# 0       10.36      US  2022-06-15 20:43:28
# 1       12.66      PG  2022-06-15 20:46:49
# 2        1.72      RU  2022-06-15 20:46:49
# 3        8.77      SB  2022-06-15 20:46:49
# 4        1.01      US  2022-06-15 20:42:38
# 5        8.05      CA  2022-06-15 20:43:04
# 6        3.44      GB  2022-06-15 20:42:57
# 7       29.93      CL  2022-06-15 20:46:50
# 8       12.55      KI  2022-06-15 20:46:51
# 9        4.61      AU  2022-06-15 20:44:23

# %%
# Reordering the columns
new_column_order = ["City","Country","Date","Lat","Lng","Max Temp","Humidity","Cloudiness", "Wind Speed"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#             City Country                 Date      Lat       Lng  Max Temp  \
# 0     Twin Falls      US  2022-06-15 20:43:28  42.3505 -114.6445     64.92
# 1        Kavieng      PG  2022-06-15 20:46:49  -2.5744  150.7967     82.17
# 2    Nikolayevka      RU  2022-06-15 20:46:49  53.1257   47.2041     61.79
# 3          Buala      SB  2022-06-15 20:46:49  -8.1450  159.5921     81.00
# 4         Albany      US  2022-06-15 20:42:38  42.6001  -73.9662     84.58
# 5    Yellowknife      CA  2022-06-15 20:43:04  62.4560 -114.3525     72.12
# 6         Oxford      GB  2022-06-15 20:42:57  51.7522   -1.2560     68.16
# 7   Punta Arenas      CL  2022-06-15 20:46:50 -53.1500  -70.9167     44.71
# 8     Butaritari      KI  2022-06-15 20:46:51   3.0707  172.7902     81.93
# 9  Alice Springs      AU  2022-06-15 20:44:23 -23.7000  133.8833     40.55
#
#    Humidity  Cloudiness  Wind Speed
# 0        26           0       10.36
# 1        76          17       12.66
# 2        80          90        1.72
# 3        81          99        8.77
# 4        44          77        1.01
# 5        40          75        8.05
# 6        45           0        3.44
# 7        65          75       29.93
# 8        68          88       12.55
# 9        87          16        4.61

# %%
# Create the output file (CSV)
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file,index_label="City_ID")
