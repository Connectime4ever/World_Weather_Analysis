# %%
# Import the dependencies.
import numpy as np
import pandas as pd

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 783

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URl for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the time library and the datetime module from the datetime library
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data. 
city_data = []
# Print the beginning of the logging. 
print("Beginning Data Retrieval    ")
print("----------------------------")
# Create counters.
record_count =1
set_count = 1

# Create an empty list to hold the weather data. 
city_data = []
# Print the beginning of the logging. 
print("Beginning Data Retrieval    ")
print("----------------------------")
# Create counters.
record_count =1
set_count = 1# Loop through all the cities in the list.
for i, city in enumerate(cities):
    # Group cities in sets of 5o for logging purposes.
    if (i %  50 == 0 and i>= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    #Log the URL, record, and set numbers and the city. 
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})
                    

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# ----------------------------
# Beginning Data Retrieval
# ----------------------------
# Processing Record 1 of Set 1 | arraial do cabo
# Processing Record 2 of Set 1 | college
# Processing Record 3 of Set 1 | seoul
# Processing Record 4 of Set 1 | kahului
# Processing Record 5 of Set 1 | kruisfontein
# Processing Record 6 of Set 1 | yellowknife
# Processing Record 7 of Set 1 | busselton
# Processing Record 8 of Set 1 | tuktoyaktuk
# Processing Record 9 of Set 1 | santander
# Processing Record 10 of Set 1 | port alfred
# Processing Record 11 of Set 1 | kenai
# Processing Record 12 of Set 1 | punta arenas
# Processing Record 13 of Set 1 | pochutla
# Processing Record 14 of Set 1 | neiafu
# Processing Record 15 of Set 1 | samarai
# Processing Record 16 of Set 1 | iqaluit
# Processing Record 17 of Set 1 | gat
# Processing Record 18 of Set 1 | vaini
# Processing Record 19 of Set 1 | saiki
# Processing Record 20 of Set 1 | severo-kurilsk
# Processing Record 21 of Set 1 | ushuaia
# Processing Record 22 of Set 1 | borujan
# City not found. Skipping...
# Processing Record 23 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 24 of Set 1 | port lincoln
# Processing Record 25 of Set 1 | laguna
# Processing Record 26 of Set 1 | mataura
# Processing Record 27 of Set 1 | hermanus
# Processing Record 28 of Set 1 | bredasdorp
# Processing Record 29 of Set 1 | bima
# Processing Record 30 of Set 1 | limbach-oberfrohna
# Processing Record 31 of Set 1 | qaanaaq
# Processing Record 32 of Set 1 | sertanopolis
# Processing Record 33 of Set 1 | bluff
# Processing Record 34 of Set 1 | georgetown
# Processing Record 35 of Set 1 | jamestown
# Processing Record 36 of Set 1 | rikitea
# Processing Record 37 of Set 1 | hobart
# Processing Record 38 of Set 1 | lavrentiya
# Processing Record 39 of Set 1 | west bay
# Processing Record 40 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 41 of Set 1 | puerto ayora
# Processing Record 42 of Set 1 | axim
# Processing Record 43 of Set 1 | mitu
# Processing Record 44 of Set 1 | yarmouth
# Processing Record 45 of Set 1 | kudahuvadhoo
# Processing Record 46 of Set 1 | sosnovo-ozerskoye
# Processing Record 47 of Set 1 | shimanovsk
# Processing Record 48 of Set 1 | saint-philippe
# Processing Record 49 of Set 1 | belyy yar
# Processing Record 50 of Set 1 | chokurdakh
# Processing Record 1 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 2 of Set 2 | beatrice
# Processing Record 3 of Set 2 | yeovil
# Processing Record 4 of Set 2 | mae hong son
# Processing Record 5 of Set 2 | longyearbyen
# Processing Record 6 of Set 2 | atuona
# Processing Record 7 of Set 2 | hilo
# Processing Record 8 of Set 2 | raga
# Processing Record 9 of Set 2 | tome-acu
# City not found. Skipping...
# Processing Record 10 of Set 2 | vila franca do campo
# Processing Record 11 of Set 2 | riyadh
# Processing Record 12 of Set 2 | radford
# Processing Record 13 of Set 2 | port elizabeth
# Processing Record 14 of Set 2 | aras
# Processing Record 15 of Set 2 | albany
# Processing Record 16 of Set 2 | cockburn town
# Processing Record 17 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 18 of Set 2 | meyungs
# City not found. Skipping...
# Processing Record 19 of Set 2 | avarua
# Processing Record 20 of Set 2 | anchorage
# Processing Record 21 of Set 2 | arona
# Processing Record 22 of Set 2 | marsh harbour
# Processing Record 23 of Set 2 | dikson
# Processing Record 24 of Set 2 | cape town
# Processing Record 25 of Set 2 | aberdeen
# Processing Record 26 of Set 2 | vanavara
# Processing Record 27 of Set 2 | kholm
# Processing Record 28 of Set 2 | carnarvon
# Processing Record 29 of Set 2 | la tuque
# Processing Record 30 of Set 2 | san patricio
# Processing Record 31 of Set 2 | norman wells
# Processing Record 32 of Set 2 | buin
# Processing Record 33 of Set 2 | upernavik
# Processing Record 34 of Set 2 | nishihara
# Processing Record 35 of Set 2 | galesong
# Processing Record 36 of Set 2 | opuwo
# Processing Record 37 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 38 of Set 2 | kodiak
# Processing Record 39 of Set 2 | dunedin
# Processing Record 40 of Set 2 | gidole
# Processing Record 41 of Set 2 | codrington
# Processing Record 42 of Set 2 | mar del plata
# Processing Record 43 of Set 2 | barrow
# Processing Record 44 of Set 2 | new norfolk
# Processing Record 45 of Set 2 | dudinka
# Processing Record 46 of Set 2 | namibe
# Processing Record 47 of Set 2 | coihaique
# Processing Record 48 of Set 2 | urucara
# Processing Record 49 of Set 2 | mahebourg
# Processing Record 50 of Set 2 | thompson
# Processing Record 1 of Set 3 | caiaponia
# Processing Record 2 of Set 3 | soyo
# Processing Record 3 of Set 3 | clyde river
# Processing Record 4 of Set 3 | east london
# Processing Record 5 of Set 3 | sitka
# Processing Record 6 of Set 3 | tiksi
# Processing Record 7 of Set 3 | coolum beach
# Processing Record 8 of Set 3 | ati
# Processing Record 9 of Set 3 | artyk
# City not found. Skipping...
# Processing Record 10 of Set 3 | zaraza
# Processing Record 11 of Set 3 | saskylakh
# Processing Record 12 of Set 3 | te anau
# Processing Record 13 of Set 3 | esperance
# Processing Record 14 of Set 3 | alta floresta
# Processing Record 15 of Set 3 | mogadishu
# Processing Record 16 of Set 3 | kavieng
# Processing Record 17 of Set 3 | tazmalt
# Processing Record 18 of Set 3 | los algarrobos
# Processing Record 19 of Set 3 | komsomolskiy
# Processing Record 20 of Set 3 | guasdualito
# Processing Record 21 of Set 3 | torbay
# Processing Record 22 of Set 3 | mazagao
# Processing Record 23 of Set 3 | honolulu
# Processing Record 24 of Set 3 | cianjur
# Processing Record 25 of Set 3 | bjornevatn
# Processing Record 26 of Set 3 | alunitdag
# City not found. Skipping...
# Processing Record 27 of Set 3 | crab hill
# City not found. Skipping...
# Processing Record 28 of Set 3 | zubtsov
# Processing Record 29 of Set 3 | karaton
# Processing Record 30 of Set 3 | ekibastuz
# Processing Record 31 of Set 3 | tidore
# City not found. Skipping...
# Processing Record 32 of Set 3 | beyneu
# Processing Record 33 of Set 3 | nyurba
# Processing Record 34 of Set 3 | garowe
# Processing Record 35 of Set 3 | palu
# Processing Record 36 of Set 3 | las juntas
# Processing Record 37 of Set 3 | cervo
# Processing Record 38 of Set 3 | timizart
# Processing Record 39 of Set 3 | deputatskiy
# Processing Record 40 of Set 3 | sept-iles
# Processing Record 41 of Set 3 | castro
# Processing Record 42 of Set 3 | todos santos
# Processing Record 43 of Set 3 | lishu
# Processing Record 44 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 45 of Set 3 | kapaa
# Processing Record 46 of Set 3 | haines junction
# Processing Record 47 of Set 3 | jiddah
# City not found. Skipping...
# Processing Record 48 of Set 3 | najran
# Processing Record 49 of Set 3 | tapaua
# City not found. Skipping...
# Processing Record 50 of Set 3 | manggar
# Processing Record 1 of Set 4 | loreto
# Processing Record 2 of Set 4 | morehead
# Processing Record 3 of Set 4 | quatre cocos
# Processing Record 4 of Set 4 | vardo
# Processing Record 5 of Set 4 | sibolga
# Processing Record 6 of Set 4 | maniitsoq
# Processing Record 7 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 8 of Set 4 | sinnamary
# Processing Record 9 of Set 4 | lompoc
# Processing Record 10 of Set 4 | praya
# Processing Record 11 of Set 4 | hamilton
# Processing Record 12 of Set 4 | ayan
# Processing Record 13 of Set 4 | cedar city
# Processing Record 14 of Set 4 | freiberg
# Processing Record 15 of Set 4 | doha
# Processing Record 16 of Set 4 | kinchil
# Processing Record 17 of Set 4 | victoria
# Processing Record 18 of Set 4 | bengkulu
# Processing Record 19 of Set 4 | hithadhoo
# Processing Record 20 of Set 4 | souillac
# Processing Record 21 of Set 4 | ilhabela
# Processing Record 22 of Set 4 | gotsu
# Processing Record 23 of Set 4 | roald
# Processing Record 24 of Set 4 | dzhebariki-khaya
# Processing Record 25 of Set 4 | barabai
# Processing Record 26 of Set 4 | karakendzha
# City not found. Skipping...
# Processing Record 27 of Set 4 | kharp
# Processing Record 28 of Set 4 | grants
# Processing Record 29 of Set 4 | cabo san lucas
# Processing Record 30 of Set 4 | hope
# Processing Record 31 of Set 4 | havoysund
# Processing Record 32 of Set 4 | lebu
# Processing Record 33 of Set 4 | trelew
# Processing Record 34 of Set 4 | north bend
# Processing Record 35 of Set 4 | hinton
# Processing Record 36 of Set 4 | paradwip
# City not found. Skipping...
# Processing Record 37 of Set 4 | cheremukhovo
# Processing Record 38 of Set 4 | honningsvag
# Processing Record 39 of Set 4 | tasiilaq
# Processing Record 40 of Set 4 | provideniya
# Processing Record 41 of Set 4 | hermosillo
# Processing Record 42 of Set 4 | bowen
# Processing Record 43 of Set 4 | vila velha
# Processing Record 44 of Set 4 | port-gentil
# Processing Record 45 of Set 4 | rio grande
# Processing Record 46 of Set 4 | roebourne
# Processing Record 47 of Set 4 | falkoping
# City not found. Skipping...
# Processing Record 48 of Set 4 | stornoway
# Processing Record 49 of Set 4 | atasu
# Processing Record 50 of Set 4 | kargopol
# Processing Record 1 of Set 5 | bambous virieux
# Processing Record 2 of Set 5 | usinsk
# Processing Record 3 of Set 5 | airai
# Processing Record 4 of Set 5 | dothan
# Processing Record 5 of Set 5 | phan rang
# City not found. Skipping...
# Processing Record 6 of Set 5 | yeppoon
# Processing Record 7 of Set 5 | rungata
# City not found. Skipping...
# Processing Record 8 of Set 5 | camacari
# Processing Record 9 of Set 5 | pandan
# Processing Record 10 of Set 5 | almaznyy
# Processing Record 11 of Set 5 | aldan
# Processing Record 12 of Set 5 | marienburg
# Processing Record 13 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 14 of Set 5 | natal
# Processing Record 15 of Set 5 | namtsy
# Processing Record 16 of Set 5 | novikovo
# Processing Record 17 of Set 5 | trincomalee
# Processing Record 18 of Set 5 | nemuro
# Processing Record 19 of Set 5 | kabare
# Processing Record 20 of Set 5 | georgiyevka
# Processing Record 21 of Set 5 | aklavik
# Processing Record 22 of Set 5 | wamba
# Processing Record 23 of Set 5 | kirakira
# Processing Record 24 of Set 5 | flinders
# Processing Record 25 of Set 5 | conde
# Processing Record 26 of Set 5 | cherskiy
# Processing Record 27 of Set 5 | saint george
# Processing Record 28 of Set 5 | pevek
# Processing Record 29 of Set 5 | ulladulla
# Processing Record 30 of Set 5 | fortuna
# Processing Record 31 of Set 5 | ivanivka
# Processing Record 32 of Set 5 | ancud
# Processing Record 33 of Set 5 | dobrinka
# Processing Record 34 of Set 5 | colonia
# Processing Record 35 of Set 5 | touros
# Processing Record 36 of Set 5 | nelson bay
# Processing Record 37 of Set 5 | luderitz
# Processing Record 38 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 39 of Set 5 | fukue
# Processing Record 40 of Set 5 | los llanos de aridane
# Processing Record 41 of Set 5 | butaritari
# Processing Record 42 of Set 5 | darhan
# Processing Record 43 of Set 5 | estevan
# Processing Record 44 of Set 5 | talnakh
# Processing Record 45 of Set 5 | santa rosa
# Processing Record 46 of Set 5 | fairbanks
# Processing Record 47 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 48 of Set 5 | healdsburg
# Processing Record 49 of Set 5 | rocha
# Processing Record 50 of Set 5 | kavaratti
# Processing Record 1 of Set 6 | kaitangata
# Processing Record 2 of Set 6 | bundaberg
# Processing Record 3 of Set 6 | asau
# Processing Record 4 of Set 6 | chuy
# Processing Record 5 of Set 6 | nikolskoye
# Processing Record 6 of Set 6 | huaihua
# Processing Record 7 of Set 6 | petukhovo
# Processing Record 8 of Set 6 | waipawa
# Processing Record 9 of Set 6 | isangel
# Processing Record 10 of Set 6 | vestmanna
# Processing Record 11 of Set 6 | heerhugowaard
# Processing Record 12 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 13 of Set 6 | grand centre
# City not found. Skipping...
# Processing Record 14 of Set 6 | palmer
# Processing Record 15 of Set 6 | mareeba
# Processing Record 16 of Set 6 | tuatapere
# Processing Record 17 of Set 6 | ahuimanu
# Processing Record 18 of Set 6 | henties bay
# Processing Record 19 of Set 6 | dukat
# Processing Record 20 of Set 6 | baykit
# Processing Record 21 of Set 6 | albury
# Processing Record 22 of Set 6 | jalingo
# Processing Record 23 of Set 6 | mehamn
# Processing Record 24 of Set 6 | tigil
# Processing Record 25 of Set 6 | olafsvik
# Processing Record 26 of Set 6 | nguruka
# Processing Record 27 of Set 6 | zlatoustovsk
# City not found. Skipping...
# Processing Record 28 of Set 6 | alofi
# Processing Record 29 of Set 6 | tias
# Processing Record 30 of Set 6 | broome
# Processing Record 31 of Set 6 | khatanga
# Processing Record 32 of Set 6 | naryan-mar
# Processing Record 33 of Set 6 | luwuk
# Processing Record 34 of Set 6 | suileng
# Processing Record 35 of Set 6 | leningradskiy
# Processing Record 36 of Set 6 | namatanai
# Processing Record 37 of Set 6 | nenjiang
# Processing Record 38 of Set 6 | halifax
# Processing Record 39 of Set 6 | saldanha
# Processing Record 40 of Set 6 | barabinsk
# Processing Record 41 of Set 6 | santarem
# Processing Record 42 of Set 6 | alyangula
# Processing Record 43 of Set 6 | wewak
# Processing Record 44 of Set 6 | itoigawa
# Processing Record 45 of Set 6 | wuwei
# Processing Record 46 of Set 6 | lorengau
# Processing Record 47 of Set 6 | villa bruzual
# Processing Record 48 of Set 6 | tessalit
# Processing Record 49 of Set 6 | lagoa
# Processing Record 50 of Set 6 | bereda
# Processing Record 1 of Set 7 | pedana
# Processing Record 2 of Set 7 | sovetskiy
# Processing Record 3 of Set 7 | murovane
# Processing Record 4 of Set 7 | olga
# Processing Record 5 of Set 7 | shelburne
# Processing Record 6 of Set 7 | phan thiet
# Processing Record 7 of Set 7 | ventspils
# Processing Record 8 of Set 7 | luganville
# Processing Record 9 of Set 7 | east hanover
# Processing Record 10 of Set 7 | neuquen
# Processing Record 11 of Set 7 | corn island
# Processing Record 12 of Set 7 | port hedland
# Processing Record 13 of Set 7 | la ronge
# Processing Record 14 of Set 7 | barawe
# City not found. Skipping...
# Processing Record 15 of Set 7 | rawson
# Processing Record 16 of Set 7 | khormuj
# City not found. Skipping...
# Processing Record 17 of Set 7 | saint-augustin
# Processing Record 18 of Set 7 | christchurch
# Processing Record 19 of Set 7 | pontes e lacerda
# Processing Record 20 of Set 7 | bilibino
# Processing Record 21 of Set 7 | itarema
# Processing Record 22 of Set 7 | phayakkhaphum phisai
# Processing Record 23 of Set 7 | ponta delgada
# Processing Record 24 of Set 7 | portland
# Processing Record 25 of Set 7 | taltal
# Processing Record 26 of Set 7 | banda aceh
# Processing Record 27 of Set 7 | paamiut
# Processing Record 28 of Set 7 | ferrol
# Processing Record 29 of Set 7 | victor harbor
# Processing Record 30 of Set 7 | nador
# Processing Record 31 of Set 7 | leeuwarden
# Processing Record 32 of Set 7 | tsentralnyy
# City not found. Skipping...
# Processing Record 33 of Set 7 | stromness
# Processing Record 34 of Set 7 | saint-nazaire
# Processing Record 35 of Set 7 | san felipe
# Processing Record 36 of Set 7 | belushya guba
# City not found. Skipping...
# Processing Record 37 of Set 7 | saint anthony
# Processing Record 38 of Set 7 | bocaranga
# City not found. Skipping...
# Processing Record 39 of Set 7 | lovozero
# Processing Record 40 of Set 7 | mackenzie
# Processing Record 41 of Set 7 | tokur
# Processing Record 42 of Set 7 | strelka
# Processing Record 43 of Set 7 | sobolevo
# Processing Record 44 of Set 7 | ilulissat
# Processing Record 45 of Set 7 | smithers
# Processing Record 46 of Set 7 | san-pedro
# Processing Record 47 of Set 7 | bouloupari
# Processing Record 48 of Set 7 | sola
# Processing Record 49 of Set 7 | jining
# Processing Record 50 of Set 7 | bubaque
# Processing Record 1 of Set 8 | avera
# Processing Record 2 of Set 8 | mentok
# City not found. Skipping...
# Processing Record 3 of Set 8 | oktyabrskiy
# Processing Record 4 of Set 8 | filingue
# Processing Record 5 of Set 8 | nantucket
# Processing Record 6 of Set 8 | burica
# City not found. Skipping...
# Processing Record 7 of Set 8 | tianpeng
# Processing Record 8 of Set 8 | puri
# Processing Record 9 of Set 8 | cayenne
# Processing Record 10 of Set 8 | coahuayana
# Processing Record 11 of Set 8 | pinheiro machado
# Processing Record 12 of Set 8 | gornyy
# Processing Record 13 of Set 8 | ostrovnoy
# Processing Record 14 of Set 8 | san cristobal
# Processing Record 15 of Set 8 | bethel
# Processing Record 16 of Set 8 | saint-pierre
# Processing Record 17 of Set 8 | solwezi
# Processing Record 18 of Set 8 | oakland
# Processing Record 19 of Set 8 | aflu
# City not found. Skipping...
# Processing Record 20 of Set 8 | kapoeta
# Processing Record 21 of Set 8 | ardistan
# City not found. Skipping...
# Processing Record 22 of Set 8 | shuya
# Processing Record 23 of Set 8 | eldorado
# Processing Record 24 of Set 8 | harper
# Processing Record 25 of Set 8 | hasanabad
# Processing Record 26 of Set 8 | qandahar
# City not found. Skipping...
# Processing Record 27 of Set 8 | hasaki
# Processing Record 28 of Set 8 | ponta do sol
# Processing Record 29 of Set 8 | ahipara
# Processing Record 30 of Set 8 | svetlogorsk
# Processing Record 31 of Set 8 | hervey bay
# Processing Record 32 of Set 8 | dzaoudzi
# Processing Record 33 of Set 8 | nagato
# Processing Record 34 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 35 of Set 8 | north platte
# Processing Record 36 of Set 8 | riwaka
# Processing Record 37 of Set 8 | jaranwala
# Processing Record 38 of Set 8 | straumen
# Processing Record 39 of Set 8 | villarrica
# Processing Record 40 of Set 8 | sucua
# Processing Record 41 of Set 8 | khorramshahr
# Processing Record 42 of Set 8 | vostok
# Processing Record 43 of Set 8 | dyersburg
# Processing Record 44 of Set 8 | lasa
# Processing Record 45 of Set 8 | morant bay
# Processing Record 46 of Set 8 | ruatoria
# City not found. Skipping...
# Processing Record 47 of Set 8 | bandarbeyla
# Processing Record 48 of Set 8 | barstow
# Processing Record 49 of Set 8 | ushtobe
# Processing Record 50 of Set 8 | gold coast
# Processing Record 1 of Set 9 | lingao
# Processing Record 2 of Set 9 | narsaq
# Processing Record 3 of Set 9 | kuah
# Processing Record 4 of Set 9 | warrnambool
# Processing Record 5 of Set 9 | inhambane
# Processing Record 6 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 7 of Set 9 | chilca
# Processing Record 8 of Set 9 | constitucion
# Processing Record 9 of Set 9 | tsihombe
# City not found. Skipping...
# Processing Record 10 of Set 9 | berezovyy
# Processing Record 11 of Set 9 | sakakah
# Processing Record 12 of Set 9 | bida
# Processing Record 13 of Set 9 | doka
# Processing Record 14 of Set 9 | bredy
# Processing Record 15 of Set 9 | sukhumi
# Processing Record 16 of Set 9 | nushki
# Processing Record 17 of Set 9 | ocampo
# Processing Record 18 of Set 9 | katsuura
# Processing Record 19 of Set 9 | dien bien
# City not found. Skipping...
# Processing Record 20 of Set 9 | myitkyina
# Processing Record 21 of Set 9 | fort wellington
# Processing Record 22 of Set 9 | praia da vitoria
# Processing Record 23 of Set 9 | hereford
# Processing Record 24 of Set 9 | maxixe
# Processing Record 25 of Set 9 | maniago
# Processing Record 26 of Set 9 | port augusta
# Processing Record 27 of Set 9 | ambon
# Processing Record 28 of Set 9 | den helder
# Processing Record 29 of Set 9 | kirovskaya
# Processing Record 30 of Set 9 | ayr
# Processing Record 31 of Set 9 | salta
# Processing Record 32 of Set 9 | the valley
# Processing Record 33 of Set 9 | daru
# Processing Record 34 of Set 9 | margate
# Processing Record 35 of Set 9 | ambilobe
# Processing Record 36 of Set 9 | nanortalik
# Processing Record 37 of Set 9 | fort nelson
# Processing Record 38 of Set 9 | dwarka
# Processing Record 39 of Set 9 | poum
# Processing Record 40 of Set 9 | zyryanka
# Processing Record 41 of Set 9 | wa
# City not found. Skipping...
# Processing Record 42 of Set 9 | lamar
# Processing Record 43 of Set 9 | charters towers
# Processing Record 44 of Set 9 | bentiu
# Processing Record 45 of Set 9 | gorin
# Processing Record 46 of Set 9 | barbar
# City not found. Skipping...
# Processing Record 47 of Set 9 | mersing
# Processing Record 48 of Set 9 | tome
# Processing Record 49 of Set 9 | chato
# Processing Record 50 of Set 9 | nioro
# Processing Record 1 of Set 10 | necochea
# Processing Record 2 of Set 10 | yulara
# Processing Record 3 of Set 10 | satitoa
# City not found. Skipping...
# Processing Record 4 of Set 10 | okha
# Processing Record 5 of Set 10 | moron
# Processing Record 6 of Set 10 | evensk
# Processing Record 7 of Set 10 | paraiso
# Processing Record 8 of Set 10 | bilma
# Processing Record 9 of Set 10 | dolores
# Processing Record 10 of Set 10 | baruun-urt
# Processing Record 11 of Set 10 | strezhevoy
# Processing Record 12 of Set 10 | novyye burasy
# Processing Record 13 of Set 10 | burgeo
# Processing Record 14 of Set 10 | camabatela
# Processing Record 15 of Set 10 | homer
# Processing Record 16 of Set 10 | chiredzi
# Processing Record 17 of Set 10 | zuwarah
# Processing Record 18 of Set 10 | lianran
# Processing Record 19 of Set 10 | qidong
# Processing Record 20 of Set 10 | muroto
# Processing Record 21 of Set 10 | mormugao
# Processing Record 22 of Set 10 | miles city
# Processing Record 23 of Set 10 | vilhena
# Processing Record 24 of Set 10 | buala
# Processing Record 25 of Set 10 | khandyga
# Processing Record 26 of Set 10 | mkushi
# Processing Record 27 of Set 10 | geraldton
# Processing Record 28 of Set 10 | clinton
# Processing Record 29 of Set 10 | mount gambier
# Processing Record 30 of Set 10 | kiunga
# Processing Record 31 of Set 10 | faanui
# Processing Record 32 of Set 10 | panaba
# Processing Record 33 of Set 10 | cuenca
# Processing Record 34 of Set 10 | chengdu
# Processing Record 35 of Set 10 | buluang
# Processing Record 36 of Set 10 | taoudenni
# Processing Record 37 of Set 10 | chicama
# Processing Record 38 of Set 10 | akhmim
# Processing Record 39 of Set 10 | ribeira grande
# Processing Record 40 of Set 10 | palaiomonastiron
# Processing Record 41 of Set 10 | gondar
# Processing Record 42 of Set 10 | bayanday
# Processing Record 43 of Set 10 | katherine
# Processing Record 44 of Set 10 | korla
# Processing Record 45 of Set 10 | bandar-e torkaman
# City not found. Skipping...
# Processing Record 46 of Set 10 | sao gabriel da cachoeira
# Processing Record 47 of Set 10 | san miguel
# Processing Record 48 of Set 10 | lakes entrance
# Processing Record 49 of Set 10 | yenagoa
# Processing Record 50 of Set 10 | montefiascone
# Processing Record 1 of Set 11 | dakar
# Processing Record 2 of Set 11 | alugan
# Processing Record 3 of Set 11 | olindina
# Processing Record 4 of Set 11 | srandakan
# Processing Record 5 of Set 11 | hualmay
# Processing Record 6 of Set 11 | yinchuan
# Processing Record 7 of Set 11 | abu dhabi
# Processing Record 8 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 9 of Set 11 | wakkanai
# Processing Record 10 of Set 11 | sioux lookout
# Processing Record 11 of Set 11 | prien
# Processing Record 12 of Set 11 | carballo
# Processing Record 13 of Set 11 | san quintin
# Processing Record 14 of Set 11 | gizo
# Processing Record 15 of Set 11 | kurilsk
# Processing Record 16 of Set 11 | chitral
# Processing Record 17 of Set 11 | sao filipe
# Processing Record 18 of Set 11 | boa vista
# Processing Record 19 of Set 11 | athabasca
# Processing Record 20 of Set 11 | raudeberg
# Processing Record 21 of Set 11 | lormi
# Processing Record 22 of Set 11 | were ilu
# Processing Record 23 of Set 11 | kjopsvik
# Processing Record 24 of Set 11 | karabulak
# Processing Record 25 of Set 11 | coari
# Processing Record 26 of Set 11 | ulukulevo
# Processing Record 27 of Set 11 | beloha
# Processing Record 28 of Set 11 | tonantins
# Processing Record 29 of Set 11 | gurupa
# Processing Record 30 of Set 11 | berlevag
# Processing Record 31 of Set 11 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 32 of Set 11 | sambava
# Processing Record 33 of Set 11 | carutapera
# Processing Record 34 of Set 11 | kennewick
# Processing Record 35 of Set 11 | madimba
# Processing Record 36 of Set 11 | seydi
# Processing Record 37 of Set 11 | pacifica
# Processing Record 38 of Set 11 | kemijarvi
# Processing Record 39 of Set 11 | maceio
# Processing Record 40 of Set 11 | istok
# Processing Record 41 of Set 11 | mount pleasant
# Processing Record 42 of Set 11 | aizawl
# Processing Record 43 of Set 11 | anar darreh
# City not found. Skipping...
# Processing Record 44 of Set 11 | coquimbo
# Processing Record 45 of Set 11 | kununurra
# Processing Record 46 of Set 11 | naze
# Processing Record 47 of Set 11 | picton
# Processing Record 48 of Set 11 | pangnirtung
# Processing Record 49 of Set 11 | kieta
# Processing Record 50 of Set 11 | tarudant
# City not found. Skipping...
# Processing Record 1 of Set 12 | baghdad
# Processing Record 2 of Set 12 | northam
# Processing Record 3 of Set 12 | karkaralinsk
# City not found. Skipping...
# Processing Record 4 of Set 12 | shakawe
# Processing Record 5 of Set 12 | lata
# Processing Record 6 of Set 12 | big rapids
# Processing Record 7 of Set 12 | juneau
# Processing Record 8 of Set 12 | turkan
# Processing Record 9 of Set 12 | umzimvubu
# City not found. Skipping...
# Processing Record 10 of Set 12 | nome
# Processing Record 11 of Set 12 | izhma
# Processing Record 12 of Set 12 | rongcheng
# Processing Record 13 of Set 12 | le port
# Processing Record 14 of Set 12 | labuhan
# Processing Record 15 of Set 12 | mabaruma
# Processing Record 16 of Set 12 | rio gallegos
# Processing Record 17 of Set 12 | caravelas
# Processing Record 18 of Set 12 | iida
# Processing Record 19 of Set 12 | salt lake city
# Processing Record 20 of Set 12 | beira
# Processing Record 21 of Set 12 | atbasar
# Processing Record 22 of Set 12 | lazaro cardenas
# Processing Record 23 of Set 12 | mandalgovi
# Processing Record 24 of Set 12 | porto novo
# Processing Record 25 of Set 12 | mersin
# Processing Record 26 of Set 12 | antofagasta
# Processing Record 27 of Set 12 | flin flon
# Processing Record 28 of Set 12 | kaseda
# Processing Record 29 of Set 12 | husavik
# Processing Record 30 of Set 12 | ballitoville
# Processing Record 31 of Set 12 | bhaderwah
# Processing Record 32 of Set 12 | sainte-marie
# Processing Record 33 of Set 12 | mandera
# Processing Record 34 of Set 12 | rajauri
# Processing Record 35 of Set 12 | namuac
# Processing Record 36 of Set 12 | muros
# Processing Record 37 of Set 12 | weligama
# Processing Record 38 of Set 12 | richards bay
# Processing Record 39 of Set 12 | saint-georges
# Processing Record 40 of Set 12 | chirawa
# Processing Record 41 of Set 12 | aykhal
# Processing Record 42 of Set 12 | upington
# Processing Record 43 of Set 12 | wasilla
# Processing Record 44 of Set 12 | solnechnyy
# Processing Record 45 of Set 12 | pingliang
# Processing Record 46 of Set 12 | zhezkazgan
# Processing Record 47 of Set 12 | mapiri
# Processing Record 48 of Set 12 | beringovskiy
# Processing Record 49 of Set 12 | chimore
# Processing Record 50 of Set 12 | piacabucu
# Processing Record 1 of Set 13 | waw
# Processing Record 2 of Set 13 | jinchang
# Processing Record 3 of Set 13 | santa elena
# Processing Record 4 of Set 13 | san luis
# Processing Record 5 of Set 13 | veshenskaya
# Processing Record 6 of Set 13 | carlyle
# Processing Record 7 of Set 13 | bairiki
# Processing Record 8 of Set 13 | hella
# Processing Record 9 of Set 13 | zabid
# Processing Record 10 of Set 13 | perpignan
# Processing Record 11 of Set 13 | bonavista
# Processing Record 12 of Set 13 | matamoros
# Processing Record 13 of Set 13 | tarakan
# Processing Record 14 of Set 13 | alice springs
# Processing Record 15 of Set 13 | kendari
# Processing Record 16 of Set 13 | jeremoabo
# Processing Record 17 of Set 13 | bahia de caraquez
# Processing Record 18 of Set 13 | suleja
# Processing Record 19 of Set 13 | hanzhong
# Processing Record 20 of Set 13 | anloga
# Processing Record 21 of Set 13 | vila do maio
# Processing Record 22 of Set 13 | berdigestyakh
# Processing Record 23 of Set 13 | magog
# Processing Record 24 of Set 13 | sabha
# Processing Record 25 of Set 13 | cairns
# Processing Record 26 of Set 13 | galiwinku
# City not found. Skipping...
# Processing Record 27 of Set 13 | viedma
# Processing Record 28 of Set 13 | malanje
# Processing Record 29 of Set 13 | chulman
# Processing Record 30 of Set 13 | atocha
# Processing Record 31 of Set 13 | samusu
# City not found. Skipping...
# Processing Record 32 of Set 13 | bolungarvik
# City not found. Skipping...
# Processing Record 33 of Set 13 | tumannyy
# City not found. Skipping...
# Processing Record 34 of Set 13 | igarka
# Processing Record 35 of Set 13 | matara
# Processing Record 36 of Set 13 | capinopolis
# Processing Record 37 of Set 13 | dicabisagan
# Processing Record 38 of Set 13 | lusambo
# Processing Record 39 of Set 13 | busembatia
# Processing Record 40 of Set 13 | ostersund
# Processing Record 41 of Set 13 | manaure
# Processing Record 42 of Set 13 | hambantota
# Processing Record 43 of Set 13 | savinskiy
# Processing Record 44 of Set 13 | nuuk
# Processing Record 45 of Set 13 | grand gaube
# Processing Record 46 of Set 13 | emba
# Processing Record 47 of Set 13 | sakhon nakhon
# Processing Record 48 of Set 13 | chahuites
# Processing Record 49 of Set 13 | imeni poliny osipenko
# Processing Record 50 of Set 13 | broken hill
# Processing Record 1 of Set 14 | basco
# Processing Record 2 of Set 14 | camacha
# Processing Record 3 of Set 14 | timmins
# Processing Record 4 of Set 14 | westport
# Processing Record 5 of Set 14 | red bluff
# Processing Record 6 of Set 14 | belmonte
# Processing Record 7 of Set 14 | ahero
# Processing Record 8 of Set 14 | yurga
# Processing Record 9 of Set 14 | atar
# Processing Record 10 of Set 14 | mount isa
# Processing Record 11 of Set 14 | udachnyy
# Processing Record 12 of Set 14 | angra
# City not found. Skipping...
# Processing Record 13 of Set 14 | srednyaya yelyuzan
# Processing Record 14 of Set 14 | wang saphung
# Processing Record 15 of Set 14 | mascali
# Processing Record 16 of Set 14 | kyren
# Processing Record 17 of Set 14 | mawlaik
# Processing Record 18 of Set 14 | shirokiy
# Processing Record 19 of Set 14 | tlahualilo
# City not found. Skipping...
# Processing Record 20 of Set 14 | quepos
# Processing Record 21 of Set 14 | whitecourt
# Processing Record 22 of Set 14 | shahreza
# Processing Record 23 of Set 14 | bud
# Processing Record 24 of Set 14 | huarmey
# Processing Record 25 of Set 14 | tobol
# Processing Record 26 of Set 14 | senov
# Processing Record 27 of Set 14 | sampit
# Processing Record 28 of Set 14 | zyryanskoye
# Processing Record 29 of Set 14 | noyabrsk
# Processing Record 30 of Set 14 | vitim
# Processing Record 31 of Set 14 | conceicao do araguaia
# Processing Record 32 of Set 14 | hami
# Processing Record 33 of Set 14 | akyab
# Processing Record 34 of Set 14 | bulaevo
# Processing Record 35 of Set 14 | grindavik
# Processing Record 36 of Set 14 | tarko-sale
# Processing Record 37 of Set 14 | noumea
# Processing Record 38 of Set 14 | nkhotakota
# Processing Record 39 of Set 14 | finnsnes
# Processing Record 40 of Set 14 | halalo
# City not found. Skipping...
# Processing Record 41 of Set 14 | xinyu
# Processing Record 42 of Set 14 | apatou
# Processing Record 43 of Set 14 | linguere
# Processing Record 44 of Set 14 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 45 of Set 14 | corrente
# Processing Record 46 of Set 14 | lokosovo
# Processing Record 47 of Set 14 | naantali
# Processing Record 48 of Set 14 | cabedelo
# Processing Record 49 of Set 14 | houma
# Processing Record 50 of Set 14 | grand-lahou
# Processing Record 1 of Set 15 | high rock
# Processing Record 2 of Set 15 | patos
# Processing Record 3 of Set 15 | yar-sale
# Processing Record 4 of Set 15 | puerto del rosario
# Processing Record 5 of Set 15 | izumo
# Processing Record 6 of Set 15 | kumo
# Processing Record 7 of Set 15 | puerto baquerizo moreno
# Processing Record 8 of Set 15 | tapes
# Processing Record 9 of Set 15 | terrak
# Processing Record 10 of Set 15 | sisimiut
# Processing Record 11 of Set 15 | kuybyshevo
# Processing Record 12 of Set 15 | bonito
# Processing Record 13 of Set 15 | whitehorse
# Processing Record 14 of Set 15 | nevers
# Processing Record 15 of Set 15 | galgani
# City not found. Skipping...
# Processing Record 16 of Set 15 | yokadouma
# Processing Record 17 of Set 15 | zhigansk
# Processing Record 18 of Set 15 | bargal
# City not found. Skipping...
# Processing Record 19 of Set 15 | honiara
# Processing Record 20 of Set 15 | george
# Processing Record 21 of Set 15 | nikki
# Processing Record 22 of Set 15 | fenoarivo atsinanana
# Processing Record 23 of Set 15 | ereymentau
# Processing Record 24 of Set 15 | asfi
# Processing Record 25 of Set 15 | carupano
# Processing Record 26 of Set 15 | shepsi
# Processing Record 27 of Set 15 | tiznit
# Processing Record 28 of Set 15 | vestmannaeyjar
# Processing Record 29 of Set 15 | yopal
# Processing Record 30 of Set 15 | angoche
# Processing Record 31 of Set 15 | sao joao da barra
# Processing Record 32 of Set 15 | nsanje
# Processing Record 33 of Set 15 | languyan
# Processing Record 34 of Set 15 | safaga
# Processing Record 35 of Set 15 | la macarena
# Processing Record 36 of Set 15 | ngukurr
# City not found. Skipping...
# Processing Record 37 of Set 15 | tautira
# Processing Record 38 of Set 15 | lake cowichan
# Processing Record 39 of Set 15 | dubbo
# Processing Record 40 of Set 15 | port hardy
# Processing Record 41 of Set 15 | westerland
# Processing Record 42 of Set 15 | atlantis
# Processing Record 43 of Set 15 | atambua
# Processing Record 44 of Set 15 | krasnovishersk
# Processing Record 45 of Set 15 | rio cuarto
# Processing Record 46 of Set 15 | dabat
# Processing Record 47 of Set 15 | palana
# Processing Record 48 of Set 15 | hofn
# Processing Record 49 of Set 15 | mahibadhoo
# Processing Record 50 of Set 15 | pizarro
# Processing Record 1 of Set 16 | kijang
# Processing Record 2 of Set 16 | winfield
# Processing Record 3 of Set 16 | korem
# Processing Record 4 of Set 16 | pascagoula
# Processing Record 5 of Set 16 | leh
# Processing Record 6 of Set 16 | comodoro rivadavia
# Processing Record 7 of Set 16 | teneguiban
# City not found. Skipping...
# Processing Record 8 of Set 16 | sagacad
# Processing Record 9 of Set 16 | tezu
# Processing Record 10 of Set 16 | makhinjauri
# Processing Record 11 of Set 16 | bulawayo
# Processing Record 12 of Set 16 | santa ines
# Processing Record 13 of Set 16 | sohag
# Processing Record 14 of Set 16 | sur
# Processing Record 15 of Set 16 | camopi
# Processing Record 16 of Set 16 | youghal
# Processing Record 17 of Set 16 | nhlangano
# Processing Record 18 of Set 16 | shibarghan
# City not found. Skipping...
# Processing Record 19 of Set 16 | malakal
# Processing Record 20 of Set 16 | manaquiri
# Processing Record 21 of Set 16 | cumberland
# Processing Record 22 of Set 16 | boca do acre
# Processing Record 23 of Set 16 | ulyanovka
# Processing Record 24 of Set 16 | thurso
# Processing Record 25 of Set 16 | merauke
# Processing Record 26 of Set 16 | egvekinot
# Processing Record 27 of Set 16 | trairi
# Processing Record 28 of Set 16 | umm kaddadah
# Processing Record 29 of Set 16 | mayo
# Processing Record 30 of Set 16 | elizabeth city
# Processing Record 31 of Set 16 | taksimo
# Processing Record 32 of Set 16 | lhokseumawe
# Processing Record 33 of Set 16 | urumqi
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Arraial Do Cabo -22.9661  -42.0278     67.86        94           0
# 1          College  64.8569 -147.8028     60.78        60          75
# 2            Seoul  37.5683  126.9778     76.39        94         100
# 3          Kahului  20.8947 -156.4700     74.84        80          40
# 4     Kruisfontein -34.0033   24.7314     57.88        52         100
# 5      Yellowknife  62.4560 -114.3525     51.57        66           3
# 6        Busselton -33.6500  115.3333     55.15        83          50
# 7      Tuktoyaktuk  69.4541 -133.0374     40.24        73         100
# 8        Santander  43.4647   -3.8044     68.61        87          75
# 9      Port Alfred -33.5906   26.8910     71.19        59         100
#
#    Wind Speed Country   Current Description
# 0        2.30      BR             clear sky
# 1        4.61      US                 smoke
# 2       14.97      KR  heavy intensity rain
# 3        9.22      US      scattered clouds
# 4        7.67      ZA       overcast clouds
# 5        4.00      CA             clear sky
# 6        8.48      AU      scattered clouds
# 7        8.81      CA       overcast clouds
# 8       17.27      ES         broken clouds
# 9        7.00      ZA       overcast clouds

# %%
# Reordering the columns
new_column_order = ["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness", "Wind Speed","Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Arraial Do Cabo      BR -22.9661  -42.0278     67.86        94           0
# 1          College      US  64.8569 -147.8028     60.78        60          75
# 2            Seoul      KR  37.5683  126.9778     76.39        94         100
# 3          Kahului      US  20.8947 -156.4700     74.84        80          40
# 4     Kruisfontein      ZA -34.0033   24.7314     57.88        52         100
# 5      Yellowknife      CA  62.4560 -114.3525     51.57        66           3
# 6        Busselton      AU -33.6500  115.3333     55.15        83          50
# 7      Tuktoyaktuk      CA  69.4541 -133.0374     40.24        73         100
# 8        Santander      ES  43.4647   -3.8044     68.61        87          75
# 9      Port Alfred      ZA -33.5906   26.8910     71.19        59         100
#
#    Wind Speed   Current Description
# 0        2.30             clear sky
# 1        4.61                 smoke
# 2       14.97  heavy intensity rain
# 3        9.22      scattered clouds
# 4        7.67       overcast clouds
# 5        4.00             clear sky
# 6        8.48      scattered clouds
# 7        8.81       overcast clouds
# 8       17.27         broken clouds
# 9        7.00       overcast clouds

# %%
# Create the output file (CSV)
output_data_file = "cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file,index_label="City_ID")

# %%
city_data_df.to_csv("./Weather_Database/WeatherPy_Database.csv")
