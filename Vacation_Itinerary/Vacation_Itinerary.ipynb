# %% [markdown]
# ## Deliverable 3. Create a Travel Itinerary Map.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps

# Import API key
from config2 import g_key

# Configure gmaps
gmaps.configure(api_key=g_key)

# %%
# 1. Read the WeatherPy_vacation.csv into a DataFrame.
vacation_df = pd.read_csv("../Vacation_Search/WeatherPy_vacation.csv")
vacation_df.head()
# Out:
#    Unnamed: 0     City Country  Max Temp   Current Description      Lat  \
# 0           2    Seoul      KR     76.39  heavy intensity rain  37.5683
# 1          13   Neiafu      TO     76.32       overcast clouds -18.6500
# 2          14  Samarai      PG     79.75       overcast clouds -10.6167
# 3          18    Saiki      JP     78.75      scattered clouds  32.9500
# 4          22   Laguna      US     79.02             clear sky  38.4210
#
#         Lng                                         Hotel Name
# 0  126.9778                                            롯데호텔 서울
# 1 -173.9833              Mystic Sands Beachfront Accommodation
# 2  150.6667                                          Nuli Sapi
# 3  131.9000                                            （株）サンテツ
# 4 -121.4238  Holiday Inn Express & Suites Elk Grove Central...

# %%
# 2. Using the template add the city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Weather</dt><dd>{Current Description} and</dd>
{Max Temp} °F</dd>
</dl>
"""

# 3a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in vacation_df.iterrows()]

# 3b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = vacation_df[["Lat", "Lng"]]

# %%
# !pip install gmaps
# !jupyter nbextension enable --py gmaps
# !jupyter nbextension enable --py widgetsnbextension
# Out:
# Requirement already satisfied: gmaps in c:\users\vicae\anaconda3\envs\weatherpy\lib\site-packages (0.9.0)
# Requirement already satisfied: ipywidgets>=7.0.0 in c:\users\vicae\anaconda3\envs\weatherpy\lib\site-packages (from gmaps) (7.7.0)
# Requirement already satisfied: geojson>=2.0.0 in c:\users\vicae\anaconda3\envs\weatherpy\lib\site-packages (from gmaps) (2.5.0)
# Requirement already satisfied: ipython>=5.3.0 in c:\users\vicae\anaconda3\envs\weatherpy\lib\site-packages (from gmaps) (7.31.1)
# Requirement already satisfied: six in c:\users\vicae\anaconda3\envs\weatherpy\lib\site-packages (from gmaps) (1.16.0)
# Requirement already satisfied: traitlets>=4.3.0 in c:\users\vicae\anaconda3\envs\weatherpy\lib\site-packages (from gmaps) (5.1.1)
# Requirement already satisfied: setuptools>=18.5 in c:\users\vicae\anaconda3\envs\weatherpy\lib\site-packages (from ipython>=5.3.0->gmaps) (61.2.0)
# Requirement already satisfied: decorator in c:\users\vicae\anaconda3\envs\weatherpy\lib\site-packages (from ipython>=5.3.0->gmaps) (5.1.1)
# Requirement already satisfied: backcall in c:\users\vicae\anaconda3\envs\weatherpy\lib\site-packages (from ipython>=5.3.0->gmaps) (0.2.0)
# Requirement already satisfied: jedi>=0.16 in c:\users\vicae\anaconda3\envs\weatherpy\lib\site-packages (from ipython>=5.3.0->gmaps) (0.18.1)
# Requirement already satisfied: pickleshare in c:\users\vicae\anaconda3\envs\weatherpy\lib\site-packages (from ipython>=5.3.0->gmaps) (0.7.5)
# Requirement already satisfied: pygments in c:\users\vicae\anaconda3\envs\weatherpy\lib\site-packages (from ipython>=5.3.0->gmaps) (2.11.2)
# Requirement already satisfied: colorama in c:\users\vicae\anaconda3\envs\weatherpy\lib\site-packages (from ipython>=5.3.0->gmaps) (0.4.4)
# Requirement already satisfied: matplotlib-inline in c:\users\vicae\anaconda3\envs\weatherpy\lib\site-packages (from ipython>=5.3.0->gmaps) (0.1.2)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\vicae\anaconda3\envs\weatherpy\lib\site-packages (from ipython>=5.3.0->gmaps) (3.0.20)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\vicae\anaconda3\envs\weatherpy\lib\site-packages (from ipywidgets>=7.0.0->gmaps) (0.2.0)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\vicae\anaconda3\envs\weatherpy\lib\site-packages (from ipywidgets>=7.0.0->gmaps) (5.3.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in c:\users\vicae\anaconda3\envs\weatherpy\lib\site-packages (from ipywidgets>=7.0.0->gmaps) (3.6.0)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\vicae\anaconda3\envs\weatherpy\lib\site-packages (from ipywidgets>=7.0.0->gmaps) (6.9.1)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\vicae\anaconda3\envs\weatherpy\lib\site-packages (from ipywidgets>=7.0.0->gmaps) (1.1.0)
# Requirement already satisfied: jupyter-client<8.0 in c:\users\vicae\anaconda3\envs\weatherpy\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (7.2.2)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in c:\users\vicae\anaconda3\envs\weatherpy\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (1.5.1)
# Requirement already satisfied: nest-asyncio in c:\users\vicae\anaconda3\envs\weatherpy\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (1.5.5)
# Requirement already satisfied: tornado<7.0,>=4.2 in c:\users\vicae\anaconda3\envs\weatherpy\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (6.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\vicae\anaconda3\envs\weatherpy\lib\site-packages (from jedi>=0.16->ipython>=5.3.0->gmaps) (0.8.3)
# Requirement already satisfied: entrypoints in c:\users\vicae\anaconda3\envs\weatherpy\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (0.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\vicae\anaconda3\envs\weatherpy\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (2.8.2)
# Requirement already satisfied: jupyter-core>=4.9.2 in c:\users\vicae\anaconda3\envs\weatherpy\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (4.10.0)
# Requirement already satisfied: pyzmq>=22.3 in c:\users\vicae\anaconda3\envs\weatherpy\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (22.3.0)
# Requirement already satisfied: pywin32>=1.0 in c:\users\vicae\anaconda3\envs\weatherpy\lib\site-packages (from jupyter-core>=4.9.2->jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (302)
# Requirement already satisfied: fastjsonschema in c:\users\vicae\anaconda3\envs\weatherpy\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (2.15.1)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\vicae\anaconda3\envs\weatherpy\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (4.4.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\vicae\anaconda3\envs\weatherpy\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (0.18.0)
# Requirement already satisfied: typing-extensions in c:\users\vicae\anaconda3\envs\weatherpy\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (4.1.1)
# Requirement already satisfied: importlib-resources>=1.4.0 in c:\users\vicae\anaconda3\envs\weatherpy\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (5.2.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\vicae\anaconda3\envs\weatherpy\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (21.4.0)
# Requirement already satisfied: importlib-metadata in c:\users\vicae\anaconda3\envs\weatherpy\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (4.11.3)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\vicae\anaconda3\envs\weatherpy\lib\site-packages (from importlib-resources>=1.4.0->jsonschema>=2.6->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (3.8.0)
# Requirement already satisfied: wcwidth in c:\users\vicae\anaconda3\envs\weatherpy\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.3.0->gmaps) (0.2.5)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\vicae\anaconda3\envs\weatherpy\lib\site-packages (from widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->gmaps) (6.4.11)
# Requirement already satisfied: prometheus-client in c:\users\vicae\anaconda3\envs\weatherpy\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->gmaps) (0.13.1)
# Requirement already satisfied: nbconvert>=5 in c:\users\vicae\anaconda3\envs\weatherpy\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->gmaps) (6.4.4)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\vicae\anaconda3\envs\weatherpy\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->gmaps) (0.13.1)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\vicae\anaconda3\envs\weatherpy\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->gmaps) (1.8.0)
# Requirement already satisfied: argon2-cffi in c:\users\vicae\anaconda3\envs\weatherpy\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->gmaps) (21.3.0)
# Requirement already satisfied: jinja2 in c:\users\vicae\anaconda3\envs\weatherpy\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->gmaps) (3.0.3)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\vicae\anaconda3\envs\weatherpy\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->gmaps) (0.8.4)
# Requirement already satisfied: bleach in c:\users\vicae\anaconda3\envs\weatherpy\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->gmaps) (4.1.0)
# Requirement already satisfied: testpath in c:\users\vicae\anaconda3\envs\weatherpy\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->gmaps) (0.5.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\vicae\anaconda3\envs\weatherpy\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->gmaps) (4.11.1)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\vicae\anaconda3\envs\weatherpy\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->gmaps) (0.5.13)
# Requirement already satisfied: jupyterlab-pygments in c:\users\vicae\anaconda3\envs\weatherpy\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->gmaps) (0.1.2)
# Requirement already satisfied: defusedxml in c:\users\vicae\anaconda3\envs\weatherpy\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->gmaps) (0.7.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\vicae\anaconda3\envs\weatherpy\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->gmaps) (1.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\vicae\anaconda3\envs\weatherpy\lib\site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->gmaps) (2.1.1)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\vicae\anaconda3\envs\weatherpy\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->gmaps) (2.0.2)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\vicae\anaconda3\envs\weatherpy\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->gmaps) (21.2.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\vicae\anaconda3\envs\weatherpy\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->gmaps) (1.15.0)
# Requirement already satisfied: pycparser in c:\users\vicae\anaconda3\envs\weatherpy\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->gmaps) (2.21)
# Requirement already satisfied: soupsieve>1.2 in c:\users\vicae\anaconda3\envs\weatherpy\lib\site-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->gmaps) (2.3.1)
# Requirement already satisfied: webencodings in c:\users\vicae\anaconda3\envs\weatherpy\lib\site-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->gmaps) (0.5.1)
# Requirement already satisfied: packaging in c:\users\vicae\anaconda3\envs\weatherpy\lib\site-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->gmaps) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\vicae\anaconda3\envs\weatherpy\lib\site-packages (from packaging->bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->gmaps) (3.0.4)
# Enabling notebook extension jupyter-gmaps/extension...
#       - Validating: ok
# Enabling notebook extension jupyter-js-widgets/extension...
#       - Validating: ok

# %%
# 4a. Add a marker layer for each city to the map.
max_temp = vacation_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,dissipating=False,
             max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)
# 4b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Set new index to City
df = vacation_df.set_index("City")
df.head()
# Out:
#          Unnamed: 0 Country  Max Temp   Current Description      Lat  \
# City
# Seoul             2      KR     76.39  heavy intensity rain  37.5683
# Neiafu           13      TO     76.32       overcast clouds -18.6500
# Samarai          14      PG     79.75       overcast clouds -10.6167
# Saiki            18      JP     78.75      scattered clouds  32.9500
# Laguna           22      US     79.02             clear sky  38.4210
#
#               Lng                                         Hotel Name
# City
# Seoul    126.9778                                            롯데호텔 서울
# Neiafu  -173.9833              Mystic Sands Beachfront Accommodation
# Samarai  150.6667                                          Nuli Sapi
# Saiki    131.9000                                            （株）サンテツ
# Laguna  -121.4238  Holiday Inn Express & Suites Elk Grove Central...

# %%
# From the map above pick 4 cities and create a vacation itinerary route to travel between the four cities. 
# 5. Create DataFrames for each city by filtering the 'vacation_df' using the loc method. 
# Hint: The starting and ending city should be the same city.

vacation_start = df.loc[["Cumberland"]]
vacation_end = df.loc[["Cumberland"]]
vacation_stop1 = df.loc[["Dothan"]]
vacation_stop2 = df.loc[["Prien"]] 
vacation_stop3 = df.loc[["Hope"]]

# %%
vacation_start.head()
# Out:
#             Unnamed: 0 Country  Max Temp Current Description      Lat  \
# City
# Cumberland         705      US      75.7           clear sky  35.0502
#
#                 Lng          Hotel Name
# City
# Cumberland -78.8664  American Eagle Inn

# %%
vacation_stop1.head()
# Out:
#         Unnamed: 0 Country  Max Temp Current Description      Lat      Lng  \
# City
# Dothan         184      US      79.0           clear sky  31.2232 -85.3905
#
#                           Hotel Name
# City
# Dothan  Courtyard by Marriott Dothan

# %%
vacation_stop2.head()
# Out:
#        Unnamed: 0 Country  Max Temp Current Description      Lat      Lng  \
# City
# Prien         463      US     79.02           clear sky  30.1819 -93.2738
#
#                                  Hotel Name
# City
# Prien  L'Auberge Casino Resort Lake Charles

# %%
vacation_stop3.head()
# Out:
#       Unnamed: 0 Country  Max Temp Current Description      Lat      Lng  \
# City
# Hope         162      US     77.07    scattered clouds  33.6671 -93.5916
#
#              Hotel Name
# City
# Hope  Best Western Hope

# %%
# 6. Get the latitude-longitude pairs as tuples from each city DataFrame using the to_numpy function and list indexing.
start = vacation_start(["Lat","Lng"]).to_numpy()
end = 
stop1 = 
stop2 = 
stop3 =
# Out:
#   File "C:\Users\vicae\AppData\Local\Temp\ipykernel_35180\3906136388.py", line 3
#     end =
#           ^
# SyntaxError: invalid syntax

# %%
# 7. Create a direction layer map using the start and end latitude-longitude pairs,
# and stop1, stop2, and stop3 as the waypoints. The travel_mode should be "DRIVING", "BICYCLING", or "WALKING".

# %%
# 8. To create a marker layer map between the four cities.
#  Combine the four city DataFrames into one DataFrame using the concat() function.
itinerary_df = pd.concat([],ignore_index=True)
itinerary_df

# %%
# 9 Using the template add city name, the country code, the weather description and maximum temperature for the city. 
info_box_template = """

"""

# 10a Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in itinerary_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = itinerary_df[["Lat", "Lng"]]

# %%
# 11a. Add a marker layer for each city to the map.

# 11b. Display the figure
fig
