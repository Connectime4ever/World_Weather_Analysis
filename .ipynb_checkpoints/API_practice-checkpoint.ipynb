# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# # Create a practice set of random latitude and longitude combinations.
# lats = [25.12903645, 25.92017388, 26.62509167, -59.98969384, 37.30571269]
# lngs = [-67.59741259, 11.09532135, 74.84233102, -76.89176677, -61.13376282]
# lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ### You can only unzip tuple once before it is removed from the computer's memory. Make sure you unzip the latitudes and longitudes into the coordinates list before moving on.

# %%
# # Use the print() function to display the latitude and longitude combinations.
# for coordinate in coordinates:
#     print(coordinate[0], coordinate[1])

# %%
# Use the citipy module to determine city based on latitude and longitude. 
from citipy import citipy

# %%
# # Use the print() function to display the latitude and longitude combinations. 
# for coordinate in coordinates:
#     print(citipy.nearest_city(coordinate[0], coordinate[1]).city_name, 
#           citipy.nearest_city(coordinate[0], coordinate[1]).country_code)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and logitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 626

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URl for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=286ca73bb4158c98f2bfe56e4234c584

# %%
# Create and endpoint URL for a city.
city_url = url + "&q=" + "Boston"
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=286ca73bb4158c98f2bfe56e4234c584&q=Boston

# %%
# Make a "Get" request for the city wheather.
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
# Create am endpoint URL for a city.
city_url = url + "&q=" + "Bston"
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [404]>

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
# Get the text of the "Get" request.
city_weather.text
# Out:
# '{"coord":{"lon":-71.0598,"lat":42.3584},"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01d"}],"base":"stations","main":{"temp":75.2,"feels_like":74.86,"temp_min":69.76,"temp_max":80.65,"pressure":1021,"humidity":52},"visibility":10000,"wind":{"speed":5.99,"deg":155,"gust":11.01},"clouds":{"all":10},"dt":1655323535,"sys":{"type":2,"id":2013408,"country":"US","sunrise":1655284013,"sunset":1655338961},"timezone":-14400,"id":4930956,"name":"Boston","cod":200}'

# %%
# Get the JSON text of the "Get" request.
city_weather.json()
# Out:
# {'coord': {'lon': -71.0598, 'lat': 42.3584},
#  'weather': [{'id': 800,
#    'main': 'Clear',
#    'description': 'clear sky',
#    'icon': '01d'}],
#  'base': 'stations',
#  'main': {'temp': 75.2,
#   'feels_like': 74.86,
#   'temp_min': 69.76,
#   'temp_max': 80.65,
#   'pressure': 1021,
#   'humidity': 52},
#  'visibility': 10000,
#  'wind': {'speed': 5.99, 'deg': 155, 'gust': 11.01},
#  'clouds': {'all': 10},
#  'dt': 1655323535,
#  'sys': {'type': 2,
#   'id': 2013408,
#   'country': 'US',
#   'sunrise': 1655284013,
#   'sunset': 1655338961},
#  'timezone': -14400,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
if city_weather.status_code == 200:
    print(f"City Weather found.")
else:
    print(f"City weather not found.")
# Out:
# City Weather found.

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Bston"
city_weather = requests.get(city_url)
if city_weather.status_code == 200:
    print(f"City Weather found.")
else:
    print(f"City weather not found.")
# Out:
# City weather not found.

# %%
# Create an endpoint URL for a city
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather.json()
# Out:
# {'coord': {'lon': -71.0598, 'lat': 42.3584},
#  'weather': [{'id': 800,
#    'main': 'Clear',
#    'description': 'clear sky',
#    'icon': '01d'}],
#  'base': 'stations',
#  'main': {'temp': 75.2,
#   'feels_like': 74.86,
#   'temp_min': 69.76,
#   'temp_max': 80.65,
#   'pressure': 1021,
#   'humidity': 52},
#  'visibility': 10000,
#  'wind': {'speed': 5.99, 'deg': 155, 'gust': 11.01},
#  'clouds': {'all': 10},
#  'dt': 1655323535,
#  'sys': {'type': 2,
#   'id': 2013408,
#   'country': 'US',
#   'sunrise': 1655284013,
#   'sunset': 1655338961},
#  'timezone': -14400,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# Get the JSON data.
boston_data = city_weather.json()

# %%
boston_data["sys"]
# Out:
# {'type': 2,
#  'id': 2013408,
#  'country': 'US',
#  'sunrise': 1655284013,
#  'sunset': 1655338961}

# %%
boston_data["sys"]["country"]
# Out:
# 'US'

# %%
boston_data["dt"]
# Out:
# 1655323535

# %%
lat = boston_data["coord"]["lat"]
lng = boston_data["coord"]["lon"]
max_temp = boston_data["main"]["temp_max"]
humidity = boston_data["main"]["humidity"]
clouds = boston_data["clouds"]["all"]
wind = boston_data["wind"]["speed"]
print(lat, lng, max_temp, humidity, clouds, wind)
# Out:
# 42.3584 -71.0598 80.65 52 10 5.99

# %%
boston_data["dt"]
# Out:
# 1655323535

# %%
# Import the datetim module from the datetime library.
from datetime import datetime
# Get the date from the JSON file.
date = boston_data["dt"]
# Convert the UTC date to date format with year, month, day, hours, minutes, and seconds.
datetime.utcfromtimestamp(date)
# Out:
# datetime.datetime(2022, 6, 15, 20, 5, 35)

# %%
datetime.utcfromtimestamp(date).strftime('%Y-%m-%d %H:%M:%S')
# Out:
# '2022-06-15 20:05:35'

# %%
# Import the time library and the datetime module from the datetime library
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data. 
city_data = []
# Print the beginning of the logging. 
print("Beginning Data Retrieval    ")
print("----------------------------")
# Create counters.
record_count =1
set_count = 1

# Create an empty list to hold the weather data. 
city_data = []
# Print the beginning of the logging. 
print("Beginning Data Retrieval    ")
print("----------------------------")
# Create counters.
record_count =1
set_count = 1# Loop through all the cities in the list.
for i, city in enumerate(cities):
    # Group cities in sets of 5o for logging purposes.
    if (i %  50 == 0 and i>= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    #Log the URL, record, and set numbers and the city. 
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# ----------------------------
# Beginning Data Retrieval
# ----------------------------
# Processing Record 1 of Set 1 | pacific grove
# Processing Record 2 of Set 1 | udachnyy
# Processing Record 3 of Set 1 | rikitea
# Processing Record 4 of Set 1 | halalo
# City not found. Skipping...
# Processing Record 5 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 6 of Set 1 | tsabong
# Processing Record 7 of Set 1 | jamestown
# Processing Record 8 of Set 1 | kaitangata
# Processing Record 9 of Set 1 | sao filipe
# Processing Record 10 of Set 1 | tidore
# City not found. Skipping...
# Processing Record 11 of Set 1 | kodiak
# Processing Record 12 of Set 1 | mayumba
# Processing Record 13 of Set 1 | timizart
# Processing Record 14 of Set 1 | pevek
# Processing Record 15 of Set 1 | narsaq
# Processing Record 16 of Set 1 | rey bouba
# Processing Record 17 of Set 1 | black river
# Processing Record 18 of Set 1 | yongchang
# Processing Record 19 of Set 1 | gijon
# Processing Record 20 of Set 1 | nikolskoye
# Processing Record 21 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 22 of Set 1 | lavrentiya
# Processing Record 23 of Set 1 | bubaque
# Processing Record 24 of Set 1 | mount gambier
# Processing Record 25 of Set 1 | arraial do cabo
# Processing Record 26 of Set 1 | atlantis
# Processing Record 27 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 28 of Set 1 | hobart
# Processing Record 29 of Set 1 | hilo
# Processing Record 30 of Set 1 | cuamba
# Processing Record 31 of Set 1 | sechura
# Processing Record 32 of Set 1 | cape town
# Processing Record 33 of Set 1 | lolua
# City not found. Skipping...
# Processing Record 34 of Set 1 | barrow
# Processing Record 35 of Set 1 | erice
# Processing Record 36 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 37 of Set 1 | port lincoln
# Processing Record 38 of Set 1 | alofi
# Processing Record 39 of Set 1 | zeya
# Processing Record 40 of Set 1 | albany
# Processing Record 41 of Set 1 | severo-kurilsk
# Processing Record 42 of Set 1 | ambon
# Processing Record 43 of Set 1 | buta
# Processing Record 44 of Set 1 | mehran
# Processing Record 45 of Set 1 | east london
# Processing Record 46 of Set 1 | gawler
# Processing Record 47 of Set 1 | punta arenas
# Processing Record 48 of Set 1 | carnarvon
# Processing Record 49 of Set 1 | mar del plata
# Processing Record 50 of Set 1 | kapaa
# Processing Record 1 of Set 2 | castro
# Processing Record 2 of Set 2 | sitka
# Processing Record 3 of Set 2 | luderitz
# Processing Record 4 of Set 2 | ponta do sol
# Processing Record 5 of Set 2 | puerto ayora
# Processing Record 6 of Set 2 | metaxades
# Processing Record 7 of Set 2 | hasaki
# Processing Record 8 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 9 of Set 2 | sur
# Processing Record 10 of Set 2 | torbay
# Processing Record 11 of Set 2 | felidhoo
# City not found. Skipping...
# Processing Record 12 of Set 2 | hermanus
# Processing Record 13 of Set 2 | bengkulu
# Processing Record 14 of Set 2 | scarborough
# Processing Record 15 of Set 2 | port elizabeth
# Processing Record 16 of Set 2 | vaini
# Processing Record 17 of Set 2 | dikson
# Processing Record 18 of Set 2 | san cristobal
# Processing Record 19 of Set 2 | esperance
# Processing Record 20 of Set 2 | bethel
# Processing Record 21 of Set 2 | ahipara
# Processing Record 22 of Set 2 | nanortalik
# Processing Record 23 of Set 2 | aykhal
# Processing Record 24 of Set 2 | alanya
# Processing Record 25 of Set 2 | tongsa
# City not found. Skipping...
# Processing Record 26 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 27 of Set 2 | nelson bay
# Processing Record 28 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 29 of Set 2 | ambilobe
# Processing Record 30 of Set 2 | dunedin
# Processing Record 31 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 32 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 33 of Set 2 | upernavik
# Processing Record 34 of Set 2 | camacha
# Processing Record 35 of Set 2 | north bend
# Processing Record 36 of Set 2 | senekal
# Processing Record 37 of Set 2 | constitucion
# Processing Record 38 of Set 2 | ushuaia
# Processing Record 39 of Set 2 | umm kaddadah
# Processing Record 40 of Set 2 | mataura
# Processing Record 41 of Set 2 | catamarca
# Processing Record 42 of Set 2 | naze
# Processing Record 43 of Set 2 | vardo
# Processing Record 44 of Set 2 | jerusalem
# Processing Record 45 of Set 2 | barcelos
# Processing Record 46 of Set 2 | qaqortoq
# Processing Record 47 of Set 2 | plettenberg bay
# Processing Record 48 of Set 2 | qaanaaq
# Processing Record 49 of Set 2 | xiongzhou
# Processing Record 50 of Set 2 | redencao
# Processing Record 1 of Set 3 | airai
# Processing Record 2 of Set 3 | iqaluit
# Processing Record 3 of Set 3 | boa vista
# Processing Record 4 of Set 3 | antofagasta
# Processing Record 5 of Set 3 | butaritari
# Processing Record 6 of Set 3 | saint george
# Processing Record 7 of Set 3 | klaksvik
# Processing Record 8 of Set 3 | dekar
# Processing Record 9 of Set 3 | yellowknife
# Processing Record 10 of Set 3 | quillota
# Processing Record 11 of Set 3 | longyearbyen
# Processing Record 12 of Set 3 | mahebourg
# Processing Record 13 of Set 3 | avarua
# Processing Record 14 of Set 3 | klosterneuburg
# Processing Record 15 of Set 3 | bredasdorp
# Processing Record 16 of Set 3 | igrim
# Processing Record 17 of Set 3 | lebu
# Processing Record 18 of Set 3 | pakokku
# Processing Record 19 of Set 3 | bluff
# Processing Record 20 of Set 3 | tasiilaq
# Processing Record 21 of Set 3 | tuktoyaktuk
# Processing Record 22 of Set 3 | pisco
# Processing Record 23 of Set 3 | nome
# Processing Record 24 of Set 3 | edd
# Processing Record 25 of Set 3 | skovorodino
# Processing Record 26 of Set 3 | santa lucia
# Processing Record 27 of Set 3 | burnie
# Processing Record 28 of Set 3 | gat
# Processing Record 29 of Set 3 | betioky
# Processing Record 30 of Set 3 | san quintin
# Processing Record 31 of Set 3 | victoria
# Processing Record 32 of Set 3 | martonvasar
# Processing Record 33 of Set 3 | gobardanga
# Processing Record 34 of Set 3 | banyo
# Processing Record 35 of Set 3 | srednekolymsk
# Processing Record 36 of Set 3 | freeport
# Processing Record 37 of Set 3 | taoudenni
# Processing Record 38 of Set 3 | port alfred
# Processing Record 39 of Set 3 | lahaina
# Processing Record 40 of Set 3 | kruisfontein
# Processing Record 41 of Set 3 | garowe
# Processing Record 42 of Set 3 | oranjestad
# Processing Record 43 of Set 3 | busselton
# Processing Record 44 of Set 3 | san policarpo
# Processing Record 45 of Set 3 | mantua
# Processing Record 46 of Set 3 | zvishavane
# Processing Record 47 of Set 3 | aswan
# Processing Record 48 of Set 3 | huarmey
# Processing Record 49 of Set 3 | tarauaca
# Processing Record 50 of Set 3 | atar
# Processing Record 1 of Set 4 | alotau
# City not found. Skipping...
# Processing Record 2 of Set 4 | port-gentil
# Processing Record 3 of Set 4 | turochak
# Processing Record 4 of Set 4 | florianopolis
# Processing Record 5 of Set 4 | new norfolk
# Processing Record 6 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 7 of Set 4 | atuona
# Processing Record 8 of Set 4 | vitoria
# Processing Record 9 of Set 4 | san lorenzo
# Processing Record 10 of Set 4 | yarmouth
# Processing Record 11 of Set 4 | tautira
# Processing Record 12 of Set 4 | khatanga
# Processing Record 13 of Set 4 | bantogon
# Processing Record 14 of Set 4 | ribeira grande
# Processing Record 15 of Set 4 | lakatoro
# Processing Record 16 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 17 of Set 4 | atambua
# Processing Record 18 of Set 4 | camopi
# Processing Record 19 of Set 4 | bay roberts
# Processing Record 20 of Set 4 | provideniya
# Processing Record 21 of Set 4 | hilton head island
# Processing Record 22 of Set 4 | pocone
# Processing Record 23 of Set 4 | normandin
# Processing Record 24 of Set 4 | wewak
# Processing Record 25 of Set 4 | faanui
# Processing Record 26 of Set 4 | kununurra
# Processing Record 27 of Set 4 | kerema
# Processing Record 28 of Set 4 | brasileia
# Processing Record 29 of Set 4 | roebourne
# Processing Record 30 of Set 4 | saskylakh
# Processing Record 31 of Set 4 | ocos
# Processing Record 32 of Set 4 | sakakah
# Processing Record 33 of Set 4 | dwarka
# Processing Record 34 of Set 4 | meulaboh
# Processing Record 35 of Set 4 | isangel
# Processing Record 36 of Set 4 | lerwick
# Processing Record 37 of Set 4 | batagay-alyta
# Processing Record 38 of Set 4 | asau
# Processing Record 39 of Set 4 | exeter
# Processing Record 40 of Set 4 | el dorado
# Processing Record 41 of Set 4 | margate
# Processing Record 42 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 43 of Set 4 | bilibino
# Processing Record 44 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 45 of Set 4 | louisbourg
# City not found. Skipping...
# Processing Record 46 of Set 4 | ancud
# Processing Record 47 of Set 4 | urengoy
# Processing Record 48 of Set 4 | tasbuget
# City not found. Skipping...
# Processing Record 49 of Set 4 | tevaitoa
# Processing Record 50 of Set 4 | clyde river
# Processing Record 1 of Set 5 | ponta delgada
# Processing Record 2 of Set 5 | saldanha
# Processing Record 3 of Set 5 | bordighera
# Processing Record 4 of Set 5 | tuatapere
# Processing Record 5 of Set 5 | guerrero negro
# Processing Record 6 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 7 of Set 5 | portland
# Processing Record 8 of Set 5 | yaan
# Processing Record 9 of Set 5 | taolanaro
# City not found. Skipping...
# Processing Record 10 of Set 5 | cayenne
# Processing Record 11 of Set 5 | juba
# Processing Record 12 of Set 5 | christchurch
# Processing Record 13 of Set 5 | formoso do araguaia
# City not found. Skipping...
# Processing Record 14 of Set 5 | dayong
# Processing Record 15 of Set 5 | emba
# Processing Record 16 of Set 5 | santiago del estero
# Processing Record 17 of Set 5 | nouadhibou
# Processing Record 18 of Set 5 | tomatlan
# Processing Record 19 of Set 5 | bako
# Processing Record 20 of Set 5 | san juan capistrano
# Processing Record 21 of Set 5 | okato
# Processing Record 22 of Set 5 | birao
# Processing Record 23 of Set 5 | mount vernon
# Processing Record 24 of Set 5 | simnas
# Processing Record 25 of Set 5 | eldikan
# City not found. Skipping...
# Processing Record 26 of Set 5 | comodoro rivadavia
# Processing Record 27 of Set 5 | pangkalanbuun
# Processing Record 28 of Set 5 | souillac
# Processing Record 29 of Set 5 | san felipe
# Processing Record 30 of Set 5 | kumluca
# Processing Record 31 of Set 5 | college
# Processing Record 32 of Set 5 | westport
# Processing Record 33 of Set 5 | codrington
# Processing Record 34 of Set 5 | olinda
# Processing Record 35 of Set 5 | vurnary
# Processing Record 36 of Set 5 | fortuna
# Processing Record 37 of Set 5 | soyo
# Processing Record 38 of Set 5 | halifax
# Processing Record 39 of Set 5 | marsh harbour
# Processing Record 40 of Set 5 | faya
# Processing Record 41 of Set 5 | padang
# Processing Record 42 of Set 5 | lorengau
# Processing Record 43 of Set 5 | marienburg
# Processing Record 44 of Set 5 | ulladulla
# Processing Record 45 of Set 5 | norman wells
# Processing Record 46 of Set 5 | leningradskiy
# Processing Record 47 of Set 5 | quepos
# Processing Record 48 of Set 5 | yatou
# Processing Record 49 of Set 5 | tabuk
# Processing Record 50 of Set 5 | balikpapan
# Processing Record 1 of Set 6 | deputatskiy
# Processing Record 2 of Set 6 | chapais
# Processing Record 3 of Set 6 | kemijarvi
# Processing Record 4 of Set 6 | dickinson
# Processing Record 5 of Set 6 | sisimiut
# Processing Record 6 of Set 6 | troitskoye
# Processing Record 7 of Set 6 | vao
# Processing Record 8 of Set 6 | lamar
# Processing Record 9 of Set 6 | siwani
# City not found. Skipping...
# Processing Record 10 of Set 6 | pontal do parana
# Processing Record 11 of Set 6 | san rafael
# Processing Record 12 of Set 6 | hokitika
# Processing Record 13 of Set 6 | knysna
# Processing Record 14 of Set 6 | krasnoborsk
# Processing Record 15 of Set 6 | byron bay
# Processing Record 16 of Set 6 | puerto del rosario
# Processing Record 17 of Set 6 | salalah
# Processing Record 18 of Set 6 | matara
# Processing Record 19 of Set 6 | yumen
# Processing Record 20 of Set 6 | mahon
# Processing Record 21 of Set 6 | paamiut
# Processing Record 22 of Set 6 | utiroa
# City not found. Skipping...
# Processing Record 23 of Set 6 | katsuura
# Processing Record 24 of Set 6 | mariestad
# Processing Record 25 of Set 6 | kajaani
# Processing Record 26 of Set 6 | tual
# Processing Record 27 of Set 6 | felipe carrillo puerto
# Processing Record 28 of Set 6 | zheleznodorozhnyy
# Processing Record 29 of Set 6 | achutupo
# Processing Record 30 of Set 6 | chebsara
# Processing Record 31 of Set 6 | waw
# Processing Record 32 of Set 6 | olga
# Processing Record 33 of Set 6 | telma
# Processing Record 34 of Set 6 | caravelas
# Processing Record 35 of Set 6 | karratha
# Processing Record 36 of Set 6 | hamilton
# Processing Record 37 of Set 6 | wasilla
# Processing Record 38 of Set 6 | chokurdakh
# Processing Record 39 of Set 6 | hithadhoo
# Processing Record 40 of Set 6 | ust-koksa
# Processing Record 41 of Set 6 | necochea
# Processing Record 42 of Set 6 | thompson
# Processing Record 43 of Set 6 | kavieng
# Processing Record 44 of Set 6 | namibe
# Processing Record 45 of Set 6 | eirunepe
# Processing Record 46 of Set 6 | geraldton
# Processing Record 47 of Set 6 | podbelsk
# City not found. Skipping...
# Processing Record 48 of Set 6 | altamont
# Processing Record 49 of Set 6 | oranzherei
# Processing Record 50 of Set 6 | sistranda
# Processing Record 1 of Set 7 | duma
# Processing Record 2 of Set 7 | gazimurskiy zavod
# Processing Record 3 of Set 7 | lazaro cardenas
# Processing Record 4 of Set 7 | meadow lake
# Processing Record 5 of Set 7 | georgetown
# Processing Record 6 of Set 7 | fairbanks
# Processing Record 7 of Set 7 | warri
# Processing Record 8 of Set 7 | kamaishi
# Processing Record 9 of Set 7 | touros
# Processing Record 10 of Set 7 | mabaruma
# Processing Record 11 of Set 7 | kieta
# Processing Record 12 of Set 7 | roald
# Processing Record 13 of Set 7 | moron
# Processing Record 14 of Set 7 | aklavik
# Processing Record 15 of Set 7 | akdepe
# Processing Record 16 of Set 7 | tiksi
# Processing Record 17 of Set 7 | bunia
# Processing Record 18 of Set 7 | novyy urengoy
# Processing Record 19 of Set 7 | bambous virieux
# Processing Record 20 of Set 7 | phan rang
# City not found. Skipping...
# Processing Record 21 of Set 7 | mayo
# Processing Record 22 of Set 7 | hofn
# Processing Record 23 of Set 7 | alvarado
# Processing Record 24 of Set 7 | half moon bay
# Processing Record 25 of Set 7 | praia da vitoria
# Processing Record 26 of Set 7 | ugoofaaru
# Processing Record 27 of Set 7 | chifeng
# Processing Record 28 of Set 7 | xichang
# Processing Record 29 of Set 7 | la asuncion
# Processing Record 30 of Set 7 | ahtopol
# Processing Record 31 of Set 7 | north platte
# Processing Record 32 of Set 7 | te anau
# Processing Record 33 of Set 7 | tselina
# Processing Record 34 of Set 7 | lompoc
# Processing Record 35 of Set 7 | nha trang
# Processing Record 36 of Set 7 | praia
# Processing Record 37 of Set 7 | trelew
# Processing Record 38 of Set 7 | matveyev kurgan
# Processing Record 39 of Set 7 | shu
# Processing Record 40 of Set 7 | bela vista de goias
# Processing Record 41 of Set 7 | vila
# Processing Record 42 of Set 7 | anito
# Processing Record 43 of Set 7 | big spring
# Processing Record 44 of Set 7 | saint-philippe
# Processing Record 45 of Set 7 | ilulissat
# Processing Record 46 of Set 7 | okhotsk
# Processing Record 47 of Set 7 | mutare
# Processing Record 48 of Set 7 | rathdrum
# Processing Record 49 of Set 7 | yamada
# Processing Record 50 of Set 7 | saryozek
# Processing Record 1 of Set 8 | saint-joseph
# Processing Record 2 of Set 8 | broome
# Processing Record 3 of Set 8 | mogadishu
# Processing Record 4 of Set 8 | sosnovo-ozerskoye
# Processing Record 5 of Set 8 | harper
# Processing Record 6 of Set 8 | kushima
# Processing Record 7 of Set 8 | axim
# Processing Record 8 of Set 8 | hami
# Processing Record 9 of Set 8 | saint-pierre
# Processing Record 10 of Set 8 | qovlar
# Processing Record 11 of Set 8 | weinan
# Processing Record 12 of Set 8 | chulman
# Processing Record 13 of Set 8 | tsagan aman
# Processing Record 14 of Set 8 | mineiros
# Processing Record 15 of Set 8 | liku
# Processing Record 16 of Set 8 | zheshart
# Processing Record 17 of Set 8 | kahului
# Processing Record 18 of Set 8 | uk
# City not found. Skipping...
# Processing Record 19 of Set 8 | hede
# Processing Record 20 of Set 8 | riyadh
# Processing Record 21 of Set 8 | jiazi
# Processing Record 22 of Set 8 | waounde
# Processing Record 23 of Set 8 | husavik
# Processing Record 24 of Set 8 | clinton
# Processing Record 25 of Set 8 | navahrudak
# Processing Record 26 of Set 8 | the valley
# Processing Record 27 of Set 8 | humaita
# Processing Record 28 of Set 8 | evensk
# Processing Record 29 of Set 8 | uyemskiy
# Processing Record 30 of Set 8 | collie
# Processing Record 31 of Set 8 | vestmannaeyjar
# Processing Record 32 of Set 8 | havelock
# Processing Record 33 of Set 8 | borogontsy
# Processing Record 34 of Set 8 | lagoa
# Processing Record 35 of Set 8 | guozhen
# Processing Record 36 of Set 8 | monte patria
# Processing Record 37 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 38 of Set 8 | loukhi
# Processing Record 39 of Set 8 | podor
# Processing Record 40 of Set 8 | tahta
# Processing Record 41 of Set 8 | newport
# Processing Record 42 of Set 8 | grand gaube
# Processing Record 43 of Set 8 | los llanos de aridane
# Processing Record 44 of Set 8 | tokur
# Processing Record 45 of Set 8 | dhidhdhoo
# Processing Record 46 of Set 8 | landang
# City not found. Skipping...
# Processing Record 47 of Set 8 | ialibu
# Processing Record 48 of Set 8 | kandrian
# Processing Record 49 of Set 8 | marsa matruh
# Processing Record 50 of Set 8 | dolores
# Processing Record 1 of Set 9 | buala
# Processing Record 2 of Set 9 | naica
# Processing Record 3 of Set 9 | gravdal
# Processing Record 4 of Set 9 | auki
# Processing Record 5 of Set 9 | alice springs
# Processing Record 6 of Set 9 | poum
# Processing Record 7 of Set 9 | port hardy
# Processing Record 8 of Set 9 | semporna
# Processing Record 9 of Set 9 | hohhot
# Processing Record 10 of Set 9 | sao joao da barra
# Processing Record 11 of Set 9 | klaebu
# Processing Record 12 of Set 9 | myitkyina
# Processing Record 13 of Set 9 | cherskiy
# Processing Record 14 of Set 9 | egvekinot
# Processing Record 15 of Set 9 | shingu
# Processing Record 16 of Set 9 | chara
# Processing Record 17 of Set 9 | katherine
# Processing Record 18 of Set 9 | sorvag
# City not found. Skipping...
# Processing Record 19 of Set 9 | iranshahr
# Processing Record 20 of Set 9 | havre-saint-pierre
# Processing Record 21 of Set 9 | chuy
# Processing Record 22 of Set 9 | makakilo city
# Processing Record 23 of Set 9 | attawapiskat
# City not found. Skipping...
# Processing Record 24 of Set 9 | baymak
# Processing Record 25 of Set 9 | talnakh
# Processing Record 26 of Set 9 | pangoa
# Processing Record 27 of Set 9 | morant bay
# Processing Record 28 of Set 9 | igarka
# Processing Record 29 of Set 9 | sacama
# Processing Record 30 of Set 9 | nadym
# Processing Record 31 of Set 9 | two hills
# Processing Record 32 of Set 9 | mirnyy
# Processing Record 33 of Set 9 | red bluff
# Processing Record 34 of Set 9 | belmonte
# Processing Record 35 of Set 9 | cabanas
# Processing Record 36 of Set 9 | komsomolets
# Processing Record 37 of Set 9 | ostrovnoy
# Processing Record 38 of Set 9 | whitehorse
# Processing Record 39 of Set 9 | cascais
# Processing Record 40 of Set 9 | ventspils
# Processing Record 41 of Set 9 | maridi
# Processing Record 42 of Set 9 | linshu
# City not found. Skipping...
# Processing Record 43 of Set 9 | port hedland
# Processing Record 44 of Set 9 | orhangazi
# Processing Record 45 of Set 9 | astoria
# Processing Record 46 of Set 9 | magistralnyy
# Processing Record 47 of Set 9 | tierra colorada
# Processing Record 48 of Set 9 | cockburn town
# Processing Record 49 of Set 9 | itigi
# Processing Record 50 of Set 9 | watsa
# Processing Record 1 of Set 10 | adrar
# Processing Record 2 of Set 10 | richards bay
# Processing Record 3 of Set 10 | sapa
# Processing Record 4 of Set 10 | korla
# Processing Record 5 of Set 10 | marana
# Processing Record 6 of Set 10 | lata
# Processing Record 7 of Set 10 | yefira
# City not found. Skipping...
# Processing Record 8 of Set 10 | barcelona
# Processing Record 9 of Set 10 | yuancheng
# Processing Record 10 of Set 10 | samarai
# Processing Record 11 of Set 10 | baoding
# Processing Record 12 of Set 10 | longlac
# City not found. Skipping...
# Processing Record 13 of Set 10 | mao
# Processing Record 14 of Set 10 | kabo
# Processing Record 15 of Set 10 | acapulco
# Processing Record 16 of Set 10 | tlahualilo
# City not found. Skipping...
# Processing Record 17 of Set 10 | coahuayana
# Processing Record 18 of Set 10 | le havre
# Processing Record 19 of Set 10 | abha
# Processing Record 20 of Set 10 | sorland
# Processing Record 21 of Set 10 | ambodifototra
# City not found. Skipping...
# Processing Record 22 of Set 10 | mende
# Processing Record 23 of Set 10 | wheeling
# Processing Record 24 of Set 10 | aleppo
# Processing Record 25 of Set 10 | onega
# Processing Record 26 of Set 10 | olafsvik
# Processing Record 27 of Set 10 | san patricio
# Processing Record 28 of Set 10 | sao domingos
# Processing Record 29 of Set 10 | akdagmadeni
# Processing Record 30 of Set 10 | ler
# Processing Record 31 of Set 10 | krasnoselkup
# Processing Record 32 of Set 10 | dandong
# Processing Record 33 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 34 of Set 10 | czersk
# Processing Record 35 of Set 10 | dzhuryn
# Processing Record 36 of Set 10 | lakes entrance
# Processing Record 37 of Set 10 | khlung
# Processing Record 38 of Set 10 | los alamos
# Processing Record 39 of Set 10 | kavaratti
# Processing Record 40 of Set 10 | tukrah
# Processing Record 41 of Set 10 | berdigestyakh
# Processing Record 42 of Set 10 | wenling
# Processing Record 43 of Set 10 | oktyabrskoye
# Processing Record 44 of Set 10 | kenai
# Processing Record 45 of Set 10 | kalmunai
# Processing Record 46 of Set 10 | hambantota
# Processing Record 47 of Set 10 | takoradi
# Processing Record 48 of Set 10 | villanueva
# Processing Record 49 of Set 10 | perigueux
# Processing Record 50 of Set 10 | altay
# Processing Record 1 of Set 11 | waynesville
# Processing Record 2 of Set 11 | honningsvag
# Processing Record 3 of Set 11 | tete
# Processing Record 4 of Set 11 | simbahan
# Processing Record 5 of Set 11 | zabaykalsk
# Processing Record 6 of Set 11 | bolungarvik
# City not found. Skipping...
# Processing Record 7 of Set 11 | palu
# Processing Record 8 of Set 11 | ajdabiya
# Processing Record 9 of Set 11 | petatlan
# Processing Record 10 of Set 11 | okha
# Processing Record 11 of Set 11 | fukue
# Processing Record 12 of Set 11 | enshi
# Processing Record 13 of Set 11 | lakhipur
# Processing Record 14 of Set 11 | fort nelson
# Processing Record 15 of Set 11 | qurayyat
# Processing Record 16 of Set 11 | vanavara
# Processing Record 17 of Set 11 | itaqui
# Processing Record 18 of Set 11 | asyut
# Processing Record 19 of Set 11 | lopatyn
# Processing Record 20 of Set 11 | ampanihy
# Processing Record 21 of Set 11 | kargasok
# Processing Record 22 of Set 11 | thunder bay
# Processing Record 23 of Set 11 | mount isa
# Processing Record 24 of Set 11 | nefteyugansk
# Processing Record 25 of Set 11 | san pedro
# Processing Record 26 of Set 11 | dingle
# Processing Record 27 of Set 11 | beringovskiy
# Processing Record 28 of Set 11 | rakai
# Processing Record 29 of Set 11 | kirakira
# Processing Record 30 of Set 11 | sabha
# Processing Record 31 of Set 11 | miranda
# Processing Record 32 of Set 11 | damietta
# Processing Record 33 of Set 11 | cidreira
# Processing Record 34 of Set 11 | trincomalee
# Processing Record 35 of Set 11 | puerto narino
# Processing Record 36 of Set 11 | moose factory
# Processing Record 37 of Set 11 | hobyo
# Processing Record 38 of Set 11 | chumikan
# Processing Record 39 of Set 11 | ewa beach
# Processing Record 40 of Set 11 | the pas
# Processing Record 41 of Set 11 | severo-yeniseyskiy
# Processing Record 42 of Set 11 | tashtyp
# Processing Record 43 of Set 11 | bandarbeyla
# Processing Record 44 of Set 11 | clovis
# Processing Record 45 of Set 11 | taki
# Processing Record 46 of Set 11 | tarakan
# Processing Record 47 of Set 11 | jacareacanga
# Processing Record 48 of Set 11 | mission bend
# Processing Record 49 of Set 11 | matagalpa
# Processing Record 50 of Set 11 | balabac
# Processing Record 1 of Set 12 | zyryanka
# Processing Record 2 of Set 12 | ust-kuyga
# Processing Record 3 of Set 12 | banda aceh
# Processing Record 4 of Set 12 | bairiki
# Processing Record 5 of Set 12 | toliary
# City not found. Skipping...
# Processing Record 6 of Set 12 | honiara
# Processing Record 7 of Set 12 | marsaxlokk
# Processing Record 8 of Set 12 | ocala
# Processing Record 9 of Set 12 | kalga
# Processing Record 10 of Set 12 | ayan
# Processing Record 11 of Set 12 | bongandanga
# Processing Record 12 of Set 12 | madimba
# Processing Record 13 of Set 12 | kolondieba
# Processing Record 14 of Set 12 | harlingen
# Processing Record 15 of Set 12 | dillon
# Processing Record 16 of Set 12 | nacogdoches
# Processing Record 17 of Set 12 | winsum
# Processing Record 18 of Set 12 | kudahuvadhoo
# Processing Record 19 of Set 12 | kodinsk
# Processing Record 20 of Set 12 | obo
# Processing Record 21 of Set 12 | sebastian
# Processing Record 22 of Set 12 | victor harbor
# Processing Record 23 of Set 12 | skjervoy
# Processing Record 24 of Set 12 | sao raimundo nonato
# Processing Record 25 of Set 12 | lasa
# Processing Record 26 of Set 12 | marawi
# Processing Record 27 of Set 12 | tongliao
# Processing Record 28 of Set 12 | rawson
# Processing Record 29 of Set 12 | mentok
# City not found. Skipping...
# Processing Record 30 of Set 12 | petropavl
# Processing Record 31 of Set 12 | gizo
# Processing Record 32 of Set 12 | corinth
# Processing Record 33 of Set 12 | poya
# Processing Record 34 of Set 12 | inhambane
# Processing Record 35 of Set 12 | coalcoman
# City not found. Skipping...
# Processing Record 36 of Set 12 | yulara
# Processing Record 37 of Set 12 | zonguldak
# Processing Record 38 of Set 12 | rorvik
# Processing Record 39 of Set 12 | mumbwa
# Processing Record 40 of Set 12 | rosarito
# Processing Record 41 of Set 12 | talakan
# Processing Record 42 of Set 12 | jalpaiguri
# Processing Record 43 of Set 12 | puerto escondido
# Processing Record 44 of Set 12 | kawalu
# Processing Record 45 of Set 12 | paralimni
# Processing Record 46 of Set 12 | victoria point
# Processing Record 47 of Set 12 | khovu-aksy
# Processing Record 48 of Set 12 | ostersund
# Processing Record 49 of Set 12 | inta
# Processing Record 50 of Set 12 | wattegama
# Processing Record 1 of Set 13 | walvis bay
# Processing Record 2 of Set 13 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 3 of Set 13 | sumbal
# Processing Record 4 of Set 13 | encruzilhada do sul
# Processing Record 5 of Set 13 | den helder
# Processing Record 6 of Set 13 | ryotsu
# Processing Record 7 of Set 13 | ocampo
# Processing Record 8 of Set 13 | guicheng
# City not found. Skipping...
# Processing Record 9 of Set 13 | koslan
# Processing Record 10 of Set 13 | san roque
# Processing Record 11 of Set 13 | kyzyl-mazhalyk
# Processing Record 12 of Set 13 | serabu
# Processing Record 13 of Set 13 | saint-augustin
# Processing Record 14 of Set 13 | bloomington
# Processing Record 15 of Set 13 | rabo de peixe
# Processing Record 16 of Set 13 | manicore
# Processing Record 17 of Set 13 | hecun
# Processing Record 18 of Set 13 | yuli
# Processing Record 19 of Set 13 | haines junction
# Processing Record 20 of Set 13 | amapa
# Processing Record 21 of Set 13 | kayakent
# Processing Record 22 of Set 13 | bidduang
# City not found. Skipping...
# Processing Record 23 of Set 13 | kosai
# Processing Record 24 of Set 13 | edgewater
# Processing Record 25 of Set 13 | wiarton
# Processing Record 26 of Set 13 | luanda
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Pacific Grove  36.6177 -121.9166     84.24        75           0
# 1       Udachnyy  66.4167  112.4000     52.45        76          16
# 2        Rikitea -23.1203 -134.9692     72.81        70          48
# 3        Tsabong -26.0217   22.4010     48.07        48           1
# 4      Jamestown  42.0970  -79.2353     90.01        69         100
# 5     Kaitangata -46.2817  169.8464     49.10        74          72
# 6     Sao Filipe  14.8961  -24.4956     73.20        85          54
# 7         Kodiak  57.7900 -152.4072     56.71        72         100
# 8        Mayumba  -3.4320   10.6554     73.15        86          52
# 9       Timizart  36.8000    4.2667     78.66        38           0
#
#    Wind Speed Country                 Date
# 0       11.50      US  2022-06-15 20:09:19
# 1       12.59      RU  2022-06-15 20:09:20
# 2        6.64      PF  2022-06-15 20:09:21
# 3        8.23      BW  2022-06-15 20:09:21
# 4        5.99      US  2022-06-15 20:09:22
# 5       15.57      NZ  2022-06-15 20:09:22
# 6        6.24      CV  2022-06-15 20:09:22
# 7        9.22      US  2022-06-15 20:09:23
# 8        6.51      GA  2022-06-15 20:09:23
# 9        5.93      DZ  2022-06-15 20:09:23
